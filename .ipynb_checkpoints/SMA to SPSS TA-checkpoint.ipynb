# %% [markdown]
# # SMA to SPSS TA

# %% [markdown]
# This notebook includes the scripts used to develop the approach to convert an SMA ontology, as exported from the SMA application as a JSON file, into the appropriate libraries, types, and synonyms for the library to be used in SPSS Modeler TA.

# %%
#parse the JSON file and iterate over the types and concepts and create text files (*.txt) of all of them.

import sys, traceback
import json, csv, string
           
ifile = "C:\\Users\\IBM_ADMIN\\Documents\\1 - Clients\\HTC\\pro00046_configuration (1).json"
ofile = "C:\\Users\\IBM_ADMIN\\Documents\\1 - Clients\\HTC\\pro00046_configuration (2).json"
                        
#replace "\'" with "'" in order to clean json                        
with open(ofile, "wt") as fout:
    with open(ifile, "rt") as fin:
        for line in fin:
            fout.write(line.replace(r"\'", "'"))

with open(ofile) as jsoninput:
    #load the JSON file into a dict
    ontology = json.load(jsoninput)
    

    
    

for i in ontology['admin-app-config']: #types
    print i, type(i)
print "====================" 
for i in ontology['admin-app-config']['analysis-config']: #types
    print i, type(i)
print "====================" 
for i in ontology['admin-app-config']['analysis-config']['ModelConfiguration'][0]: #types
    print i, type(i)
    #print ontology['admin-app-config']['analysis-config']['ModelConfiguration'][0][i]
print "===================="   

#list types/themes
for i in range(0,len(ontology['admin-app-config']['analysis-config']['ModelConfiguration'])):
    print ontology['admin-app-config']['analysis-config']['ModelConfiguration'][i]['name']
print "===================="

#list concepts in a theme
for i in range(0,len(ontology['admin-app-config']['analysis-config']['ModelConfiguration'][0]['brands'])):
    print ontology['admin-app-config']['analysis-config']['ModelConfiguration'][0]['brands'][i]['name']
print "===================="

#list terms in a concept
for i in ontology['admin-app-config']['analysis-config']['ModelConfiguration'][0]['brands'][0]['regexes']:
    print ontology['admin-app-config']['analysis-config']['ModelConfiguration'][0]['brands'][0]['regexes'][i]
    #print "  ",ontology['admin-app-config']['analysis-config']['ModelConfiguration'][0]['brands'][0]['regexes'][0][i]
c="""
print "includeTerms"
for i in range(0,len(ontology['admin-app-config']['analysis-config']['ModelConfiguration'][0]['brands'][0]['regexes'][0]['includeTerms'])):
    print "  ",ontology['admin-app-config']['analysis-config']['ModelConfiguration'][0]['brands'][0]['regexes'][0]['includeTerms'][i]
print "contextTerms"
for i in range(0,len(ontology['admin-app-config']['analysis-config']['ModelConfiguration'][0]['brands'][0]['regexes'][0]['contextTerms'])):
    print "  ",ontology['admin-app-config']['analysis-config']['ModelConfiguration'][0]['brands'][0]['regexes'][0]['contextTerms'][i]
print "excludeTerms"
for i in range(0,len(ontology['admin-app-config']['analysis-config']['ModelConfiguration'][0]['brands'][0]['regexes'][0]['excludeTerms'])):
    print "  ",ontology['admin-app-config']['analysis-config']['ModelConfiguration'][0]['brands'][0]['regexes'][0]['excludeTerms'][i]
"""
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-4d33f797f742> in <module>()
#      44 #list terms in a concept
#      45 for i in ontology['admin-app-config']['analysis-config']['ModelConfiguration'][0]['brands'][0]['regexes']:
# ---> 46     print ontology['admin-app-config']['analysis-config']['ModelConfiguration'][0]['brands'][0]['regexes'][i]
#      47     #print "  ",ontology['admin-app-config']['analysis-config']['ModelConfiguration'][0]['brands'][0]['regexes'][0][i]
#      48 c="""
#
# TypeError: list indices must be integers, not dict
# datafetcher-config <type 'unicode'>
# analysis-config <type 'unicode'>
# config_file_version <type 'unicode'>
# ====================
# ModelConfiguration <type 'unicode'>
# UrlCategories <type 'unicode'>
# ====================
# name <type 'unicode'>
# TEInclude <type 'unicode'>
# patterns <type 'unicode'>
# Role <type 'unicode'>
# brands <type 'unicode'>
# includeInFetch <type 'unicode'>
# constraints <type 'unicode'>
# ====================
# Apple
# HTC One - Battery - Negative
# HTC One - Battery - Positive
# HTC Query
# Karbonn
# LG
# Micromax
# Mobile features
# Nokia
# Samsung
# Sony
# Unique Features
# User Intention
# ====================
# Apple iPhone 4
# Apple iPhone 5
# Apple iPhone 6
# Apple Other Phone
# ====================

# %%
#parse the JSON file and iterate over the types and concepts and create text files (*.txt) of all of them.

import sys, traceback, os
import json, csv, string
import unicodedata

validFilenameChars = "-_.() %s%s" % (string.ascii_letters, string.digits)

def removeDisallowedFilenameChars(filename):
    cleanedFilename = unicodedata.normalize('NFKD', filename).encode('ASCII', 'ignore')
    return ''.join(c for c in cleanedFilename if c in validFilenameChars)



ifile = "C:\\Users\\IBM_ADMIN\\Documents\\1 - Clients\\HTC\\pro00046_configuration (1).json"
ofile = "C:\\Users\\IBM_ADMIN\\Documents\\1 - Clients\\HTC\\pro00046_configuration (2).json"
wd = "C:\\Users\\IBM_ADMIN\\Documents\\1 - Clients\\HTC\\"
                        
#replace "\'" with "'" in order to clean json                        
with open(ofile, "wt") as fout:
    with open(ifile, "rt") as fin:
        for line in fin:
            fout.write(line.replace(r"\'", "'"))

with open(ofile) as jsoninput:
    #load the JSON file into a dict
    ontology = json.load(jsoninput)
os.remove(ofile)

#this will throw an error if the folder already exists
try:
    os.mkdir("C:\\Users\\IBM_ADMIN\\Documents\\1 - Clients\\HTC\\sma_for_import")
except:
    pass

for i in range(0,len(ontology['admin-app-config']['analysis-config']['ModelConfiguration'])): #theme
    for j in range(0,len(ontology['admin-app-config']['analysis-config']['ModelConfiguration'][i]['brands'])): #concept
        for k in ontology['admin-app-config']['analysis-config']['ModelConfiguration'][i]['brands'][j]['regexes'][0].keys(): #term group
            theme_name = ontology['admin-app-config']['analysis-config']['ModelConfiguration'][i]['name']
            concept_name = ontology['admin-app-config']['analysis-config']['ModelConfiguration'][i]['brands'][j]['name']
            group_name = k
            terms = ontology['admin-app-config']['analysis-config']['ModelConfiguration'][i]['brands'][j]['regexes'][0][k]
            delimiter = " - "
            #need to make new filename safe for file system (remove forbidden characters)
            newfile = theme_name+delimiter+concept_name+delimiter+group_name+".txt"
            print removeDisallowedFilenameChars(newfile)
            with open("C:\\Users\\IBM_ADMIN\\Documents\\1 - Clients\\HTC\\sma_for_import\\" + removeDisallowedFilenameChars(newfile), 'wb') as csvoutput:
                writer = csv.writer(csvoutput, lineterminator='\r\n', quotechar='"', quoting=csv.QUOTE_NONNUMERIC)
                for m in terms:
                    print "     ",m
                    writer.writerow(m)
# Out:
# Apple - Apple iPhone 4 - includeTerms.txt
#       iphone 4
#       iphone 4s
#       iphone four
#       iphone4
# Apple - Apple iPhone 4 - contextTerms.txt
# Apple - Apple iPhone 4 - excludeTerms.txt
#       iphone 6
#       iphone six
#       iphone6
#       apple mobile
#       apple mobilephone
#       apple phone
#       apple smart phone
#       apple smartphone
#       ipad
#       Ipad
#       iPad
#       macbook
#       makbook pro
#       notebook
#       ipho?
#       iphone 5
#       iphone 5c
#       iphone 5s
#       iphone five
#       iphone5
#       iphone5s
#       iphone5c
# Apple - Apple iPhone 5 - includeTerms.txt
#       iphone 5
#       iphone 5c
#       iphone 5s
#       iphone five
#       iphone5
#       iphone5s
#       iphone5c
# Apple - Apple iPhone 5 - contextTerms.txt
# Apple - Apple iPhone 5 - excludeTerms.txt
#       iphone 4
#       iphone 4s
#       iphone four
#       iphone4
#       iphone 6
#       iphone six
#       iphone6
#       apple mobile
#       apple mobilephone
#       apple phone
#       apple smart phone
#       apple smartphone
#       pad
#       Ipad
#       iPad
#       macbook
#       makbook pro
#       notebook
#       ipho?
# Apple - Apple iPhone 6 - includeTerms.txt
#       iphone 6
#       iphone six
#       iphone6
# Apple - Apple iPhone 6 - contextTerms.txt
# Apple - Apple iPhone 6 - excludeTerms.txt
#       Ipad
#       iPad
#       macbook
#       makbook pro
#       notebook
#       ipho?
#       iphone 4
#       iphone 4s
#       iphone four
#       iphone4
#       iphone 5
#       iphone 5c
#       iphone 5s
#       iphone five
#       iphone5
#       iphone5s
#       iphone5c
#       apple mobile
#       apple mobilephone
#       apple phone
#       apple smart phone
#       apple smartphone
#       pad
# Apple - Apple Other Phone - includeTerms.txt
#       apple mobile
#       apple mobilephone
#       apple phone
#       apple smart phone
#       apple smartphone
# Apple - Apple Other Phone - contextTerms.txt
# Apple - Apple Other Phone - excludeTerms.txt
#       iphone 4
#       iphone 4s
#       iphone four
#       iphone4
#       iphone 5
#       iphone 5c
#       iphone 5s
#       iphone five
#       iphone5
#       iphone5s
#       iphone5c
#       iphone 6
#       iphone six
#       iphone6
#       pad
#       Ipad
#       iPad
#       macbook
#       makbook pro
#       notebook
#       ipho?
# HTC One - Battery - Negative - Short Battery Life - includeTerms.txt
#       short
#       shorter
#       conserve battery
#       save battery
#       drained
#       draining
#       needs better
#       needs charging
#       needs to be charged
#       using all battery
#       passable
#       worst
#       concerned
#       isn't that great
# HTC One - Battery - Negative - Short Battery Life - contextTerms.txt
#       htc one
#       m8
#       m7
#       m9
#       one v
#       one x
#       one vx
#       one sv
#       one s
#       htc 1
#       one mini
# HTC One - Battery - Negative - Short Battery Life - excludeTerms.txt
# HTC One - Battery - Positive - Long Battery Life - includeTerms.txt
#       longer
#       long
#       good
#       insane
#       awesome
#       all day
#       days
#       solid
#       phenomenal
#       loving
#       better
#       best
#       great
#       can't touch
# HTC One - Battery - Positive - Long Battery Life - contextTerms.txt
#       htc one
#       m8
#       m7
#       m9
#       one v
#       one x
#       one vx
#       one sv
#       one s
#       htc 1
#       one mini
# HTC One - Battery - Positive - Long Battery Life - excludeTerms.txt
#       needs
#       wish
#       oneplus
# HTC Query - HTC Accessories - includeTerms.txt
#       htc boombass
#       htc car
#       htcdotview
#       htc double dip
#       htc fetch
#       htc flip case
#       htc medialink hd
#       htc mini
#       htc mini.?
#       htc stereo headphones
#       htc translucent case
#       htc wireless charging case
#       htc wireless charging dock
#       dot view
#       dotview
#       htc accessories
#       htc accessory
#       htc battery
#       htc bluetooth stereoclip
# HTC Query - HTC Accessories - contextTerms.txt
# HTC Query - HTC Accessories - excludeTerms.txt
#       htc wildfire
#       htc windows phone
#       htc wings
#       t8686
#       trophy t8686
#       htc j butterfly
#       htcbutterfly
#       desire \d\d\d.?
#       htc butterfly
#       desire 300
#       desire 310
#       desire 500
#       desire 600
#       desire 601
#       desire 610
#       desire 816
#       desire bravo
#       desire hd
#       desire hd2
#       desire p
#       desire x
#       htc 500
#       htc ace
#       htc desire
#       htc.{0,6}(m7|m8)
#       htc 1
#       htc m7
#       htc m8
#       htc m8x
#       htc max
#       htc new one
#       htc one
#       htcone
#       htconem8
#       new htc one
#       one dual sim
#       one m7
#       one m8
#       one max
#       htc.{0,10}phone(s|\s|\,|\.)?
#       htc amaze 4g
#       htc aria
#       htc athena
#       htc chacha
#       htc dragon
#       htc dream
#       htc droid
#       htc eris
#       htc evo
#       htc excalibur
#       htc 7 mozart
#       htc 7 pro
#       htc 7 surround
#       htc 7 trophy
#       htc 8
#       htc 8s
#       htc 8x
#       htc 8xt
#       htc mozart
#       htc radar
#       htc surround
#       htc titan
#       htc touch pro2
#       htc touch viva
#       htc trophy
#       htc tytn
#       htc v
#       htc explorer
#       htc first
#       htc flyer
#       htc fortress
#       htc fuze
#       htc hd mini
#       htc hd2
#       htc hd7
#       htc mobile
#       htc mobilephones
#       htc phone
#       htc radiant
#       htc sensation
#       htc smart phone
#       htc smartphone
#       htc touch
#       htc z715e
#       sensation xe
#       sensation xl
#       t-mobile g1
#       htc vc
#       htc vision
#       htc vivid
#       htc vt
# HTC Query - HTC Butterfly - includeTerms.txt
#       htc butterfly
#       htc j butterfly
#       htcbutterfly
# HTC Query - HTC Butterfly - contextTerms.txt
# HTC Query - HTC Butterfly - excludeTerms.txt
#       dot view
#       dotview
#       htc accessories
#       htc accessory
#       htc battery
#       htc bluetooth stereoclip
#       htc boombass
#       htc car
#       htcdotview
#       htc double dip
#       htc fetch
#       htc flip case
#       htc medialink hd
#       htc mini
#       htc mini.?
#       htc stereo headphones
#       htc translucent case
#       htc wireless charging case
#       htc wireless charging dock
#       desire \d\d\d.?
#       desire 300
#       desire 310
#       desire 500
#       desire 600
#       desire 601
#       desire 610
#       desire 816
#       desire bravo
#       desire hd
#       desire hd2
#       desire p
#       desire x
#       htc 500
#       htc ace
#       htc desire
#       htc.{0,6}(m7|m8)
#       htc 1
#       htc m7
#       htc m8
#       htc m8x
#       htc max
#       htc new one
#       htc one
#       htcone
#       htconem8
#       new htc one
#  one dual sim
#       one m7
#       one m8
#       one max
#       htc.{0,10}phone(s|\s|\,|\.)?
#       htc amaze 4g
#       htc aria
#       htc athena
#       htc chacha
#       htc dragon
#       htc dream
#       htc droid
#       htc eris
#       htc evo
#       htc excalibur
#       htc explorer
#       htc first
#       htc flyer
#       htc fortress
#       htc fuze
#       htc hd mini
#       htc hd2
#       htc hd7
#       htc mobile
#       htc mobilephones
#       htc phone
#       htc radiant
#       htc sensation
#       htc smart phone
#       htc smartphone
#       htc touch
#       htc z715e
#       sensation xe
#       sensation xl
#       t-mobile g1
#       htc 7 mozart
#       htc 7 pro
#       htc 7 surround
#       htc 7 trophy
#       htc 8
#       htc 8s
#       htc 8x
#       htc 8xt
#       htc mozart
#       htc radar
#       htc surround
#       htc titan
#       htc touch pro2
#       htc touch viva
#       htc trophy
#       htc tytn
#       htc v
#       htc vc
#       htc vision
#       htc vivid
#       htc vt
#       htc wildfire
#       htc windows phone
#       htc wings
#       t8686
#       trophy t8686
# HTC Query - HTC Desire - includeTerms.txt
#       htc desire
#       desire \d\d\d.?
#       desire 300
#       desire 310
#       desire 500
#       desire 600
#       desire 601
#       desire 610
#       desire 816
#       desire bravo
#       desire hd
#       desire hd2
#       desire p
#       desire x
#       htc 500
#       htc ace
# HTC Query - HTC Desire - contextTerms.txt
# HTC Query - HTC Desire - excludeTerms.txt
#       dot view
#       dotview
#       htc accessories
#       htc accessory
#       htc battery
#       htc bluetooth stereoclip
#       htc boombass
#       htc car
#       htcdotview
#       htc double dip
#       htc fetch
#       htc flip case
#       htc medialink hd
#       htc mini
#       htc mini.?
#       htc stereo headphones
#       htc translucent case
#       htc wireless charging case
#       htc wireless charging dock
#       htc butterfly
#       htc j butterfly
#       htcbutterfly
#       htc.{0,6}(m7|m8)
#       htc 1
#       htc m7
#       htc m8
#       htc m8x
#       htc max
#       htc new one
#       htc one
#       htcone
#       htconem8
#       new htc one
#       one dual sim
#       one m7
#       one m8
#       one max
#       htc.{0,10}phone(s|\s|\,|\.)?
#       htc amaze 4g
#       htc aria
#       htc athena
#       htc chacha
#       htc dragon
#       htc dream
#       htc droid
#       htc eris
#       htc evo
#       htc excalibur
#       htc explorer
#       htc first
#       htc flyer
#       htc fortress
#       htc fuze
#       htc hd mini
#       htc hd2
#       htc hd7
#       htc mobile
#       htc mobilephones
#       htc phone
#       htc radiant
#       htc sensation
#       htc smart phone
#       htc smartphone
#       htc touch
#       htc z715e
#       sensation xe
#       sensation xl
#       t-mobile g1
#       htc 7 mozart
#       htc 7 pro
#       htc 7 surround
#       htc 7 trophy
#       htc 8
#       htc 8s
#       htc 8x
#       htc 8xt
#       htc mozart
#       htc radar
#       htc surround
#       htc titan
#       htc touch pro2
#       htc touch viva
#       htc trophy
#       htc tytn
#       htc v
#       htc vc
#       htc vision
#       htc vivid
#       htc vt
#       htc wildfire
#       htc windows phone
#       htc wings
#       t8686
#       trophy t8686
# HTC Query - HTC One - includeTerms.txt
#       htc.{0,6}(m7|m8)
#       htc 1
#       htc m7
#       htc m8
#       htc m8x
#       htc max
#       htc new one
#       htc one
#       htcone
#       htconem8
#       new htc one
#       one dual sim
#       one m7
#       one m8
#       one max
#       one mini
# HTC Query - HTC One - contextTerms.txt
# HTC Query - HTC One - excludeTerms.txt
#       dot view
#       dotview
#       htc accessories
#       htc accessory
#       htc battery
#       htc bluetooth stereoclip
#       htc boombass
#       htc car
#       htcdotview
#       htc double dip
#       htc fetch
#       htc flip case
#       htc medialink hd
#       htc mini
#       htc mini.?
#       htc stereo headphones
#       htc translucent case
#       htc wireless charging case
#       htc wireless charging dock
#       htc butterfly
#       htc j butterfly
#       htcbutterfly
#       desire \d\d\d.?
#       desire 300
#       desire 310
#       desire 500
#       desire 600
#       desire 601
#       desire 610
#       desire 816
#       desire bravo
#       desire hd
#       desire hd2
#       desire p
#       desire x
#       htc 500
#       htc ace
#       htc 7 pro
#       htc 7 surround
#       htc 7 trophy
#       htc 8
#       htc 8s
#       htc 8x
#       htc 8xt
#       htc mozart
#       htc radar
#       htc surround
#       htc titan
#       htc touch pro2
#       htc touch viva
#       htc trophy
#       htc tytn
#       htc v
#       htc vc
#       htc vision
#       htc vivid
#       htc vt
#       htc wildfire
#       htc windows phone
#       htc wings
#       t8686
#       trophy t8686
#       Xbox
#       htc desire
#       htc.{0,10}phone(s|\s|\,|\.)?
#       htc amaze 4g
#       htc aria
#       htc athena
#       htc chacha
#       htc dragon
#       htc dream
#       htc droid
#       htc eris
#       htc evo
#       htc excalibur
#       htc explorer
#       htc first
#       htc flyer
#       htc fortress
#       htc fuze
#       htc hd mini
#       htc hd2
#       htc hd7
#       htc mobile
#       htc mobilephones
#       htc phone
#       htc radiant
#       htc sensation
#       htc smart phone
#       htc smartphone
#       htc touch
#       htc z715e
#       sensation xe
#       sensation xl
#       t-mobile g1
#       htc 7 mozart
# HTC Query - HTC Other Phones - includeTerms.txt
#       htc.{0,10}phone(s|\s|\,|\.)?
#       htc amaze 4g
#       htc aria
#       htc athena
#       htc chacha
#       htc dragon
#       htc dream
#       htc droid
#       htc eris
#       htc evo
#       htc excalibur
#       htc explorer
#       htc first
#       htc flyer
#       htc fortress
#       htc fuze
#       htc hd mini
#       htc hd2
#       htc hd7
#       htc mobile
#       htc mobilephones
#       htc phone
#       htc radiant
#       htc sensation
#       htc smart phone
#       htc smartphone
#       htc touch
#       htc z715e
#       sensation xe
#       sensation xl
#       t-mobile g1
# HTC Query - HTC Other Phones - contextTerms.txt
# HTC Query - HTC Other Phones - excludeTerms.txt
#       dot view
#       dotview
#       htc accessories
#       htc accessory
#       htc battery
#       htc bluetooth stereoclip
#       htc boombass
#       htc car
#       htcdotview
#       htc double dip
#       htc fetch
#       htc flip case
#       htc medialink hd
#       htc mini
#       htc mini.?
#       htc stereo headphones
#       htc translucent case
#       htc wireless charging case
#       htc wireless charging dock
#       htc butterfly
#       htc j butterfly
#       htcbutterfly
#       desire \d\d\d.?
#       desire 300
#       desire 310
#       desire 500
#       desire 600
#       desire 601
#       desire 610
#       desire 816
#       desire bravo
#       desire hd
#       desire hd2
#       desire p
#       desire x
#       htc 500
#       htc ace
#       htc desire
#       htc.{0,6}(m7|m8)
#       htc 1
#       htc m7
#       htc m8
#       htc m8x
#       htc max
#       htc new one
#       htc one
#       htcone
#       htconem8
#       new htc one
#       one dual sim
#       one m7
#       one m8
#       one max
#       htc 7 mozart
#       htc 7 pro
#       htc 7 surround
#       htc 7 trophy
#       htc 8
#       htc 8s
#       htc 8x
#       htc 8xt
#       htc mozart
#       htc radar
#       htc surround
#       htc titan
#       htc touch pro2
#       htc touch viva
#       htc trophy
#       htc tytn
#       htc v
#       htc vc
#       htc vision
#       htc vivid
#       htc vt
#       htc wildfire
#       htc windows phone
#       htc wings
#       t8686
#       trophy t8686
# HTC Query - HTC Window Phone - includeTerms.txt
#       htc 7 mozart
#       htc 7 pro
#       htc 7 surround
#       htc 7 trophy
#       htc 8
#       htc 8s
#       htc 8x
#       htc 8xt
#       htc mozart
#       htc radar
#       htc surround
#       htc titan
#       htc touch pro2
#       htc touch viva
#       htc trophy
#       htc tytn
#       htc v
#       htc vc
#       htc vision
#       htc vivid
#       htc vt
#       htc wildfire
#       htc windows phone
#       htc wings
#       t8686
#       trophy t8686
# HTC Query - HTC Window Phone - contextTerms.txt
# HTC Query - HTC Window Phone - excludeTerms.txt
#       dot view
#       dotview
#       htc accessories
#       htc accessory
#       htc battery
#       htc bluetooth stereoclip
#       htc boombass
#       htc car
#       htcdotview
#       htc double dip
#       htc fetch
#       htc flip case
#       htc medialink hd
#       htc mini
#       htc mini.?
#       htc stereo headphones
#       htc translucent case
#       htc wireless charging case
#       htc wireless charging dock
#       htc butterfly
#       htc j butterfly
#       htcbutterfly
#       desire \d\d\d.?
#       desire 300
#       desire 310
#       desire 500
#       desire 600
#       desire 601
#       desire 610
#       desire 816
#       desire bravo
#       desire hd
#       desire hd2
#       desire p
#       desire x
#       htc 500
#       htc ace
#       htc desire
#       htc.{0,6}(m7|m8)
#       htc 1
#       htc m7
#       htc m8
#       htc m8x
#       htc max
#       htc new one
#       htc one
#       htcone
#       htconem8
#       new htc one
#       one dual sim
#       one m7
#       one m8
#       one max
#       htc.{0,10}phone(s|\s|\,|\.)?
#       htc amaze 4g
#       htc aria
#       htc athena
#       htc chacha
#       htc dragon
#       htc dream
#       htc droid
#       htc eris
#       htc evo
#       htc excalibur
#       htc explorer
#       htc first
#       htc flyer
#       htc fortress
#       htc fuze
#       htc hd mini
#       htc hd2
#       htc hd7
#       htc mobile
#       htc mobilephones
#       htc phone
#       htc radiant
#       htc sensation
#       htc smart phone
#       htc smartphone
#       htc touch
#       htc z715e
#       sensation xe
#       sensation xl
#       t-mobile g1
# HTC Query - one m7 - includeTerms.txt
#       one m7
# HTC Query - one m7 - contextTerms.txt
# HTC Query - one m7 - excludeTerms.txt
# HTC Query - one m8 - includeTerms.txt
#       one m8
# HTC Query - one m8 - contextTerms.txt
# HTC Query - one m8 - excludeTerms.txt
# Karbonn - Karbonn Other Phones - includeTerms.txt
#       karbonn phone
# Karbonn - Karbonn Other Phones - contextTerms.txt
# Karbonn - Karbonn Other Phones - excludeTerms.txt
#       karbonn hexa
#       karbonn octane
#       karbonn s\d
#       karbonn s1 titanium
#       karbonn s2 titanium
#       karbonn s7 titanium
#       karbonn s5 titanium
#       karbonn s9 titanium
#       karbonn titanium
#       titanium s1
#       titanium s2
#       titanium s5
#       titanium s7
#       titanium s9
# Karbonn - Karbonn Titanium - includeTerms.txt
#       karbonn hexa
#       karbonn octane
#       karbonn s\d
#       karbonn s1 titanium
#       karbonn s2 titanium
#       karbonn s7 titanium
#       karbonn s5 titanium
#       karbonn s9 titanium
#       karbonn titanium
#       titanium s1
#       titanium s2
#       titanium s5
#       titanium s7
#       titanium s9
# Karbonn - Karbonn Titanium - contextTerms.txt
# Karbonn - Karbonn Titanium - excludeTerms.txt
# LG - LG G - includeTerms.txt
#       lg g pro
#       lg g2
#       lg g3
#       lg g flex
# LG - LG G - contextTerms.txt
# LG - LG G - excludeTerms.txt
#       LG mobilephone
#       LG cell phone
#       lg l70
#       lg nexus 5
#       lg optimus
#       LG phone
#       LG smart phone
#       LG smartphone
#       LG cellphone
# LG - LG L - includeTerms.txt
#       lg l70
# LG - LG L - contextTerms.txt
# LG - LG L - excludeTerms.txt
#       lg g flex
#       lg g pro
#       lg g2
#       lg g3
#       lg nexus 5
#       lg optimus
#       LG phone
#       LG smart phone
#       LG smartphone
#       LG mobilephone
#       LG cell phone
#       LG cellphone
# LG - LG Nexus - includeTerms.txt
#       lg nexus 5
# LG - LG Nexus - contextTerms.txt
# LG - LG Nexus - excludeTerms.txt
#       lg g flex
#       lg g pro
#       lg g2
#       lg g3
#       lg l70
#       lg optimus
#       LG phone
#       LG smart phone
#       LG smartphone
#       LG mobilephone
#       LG cell phone
#       LG cellphone
# LG - LG Optimus - includeTerms.txt
#       lg optimus
# LG - LG Optimus - contextTerms.txt
# LG - LG Optimus - excludeTerms.txt
#       lg g flex
#       lg g pro
#       lg g2
#       lg g3
#       lg l70
#       lg nexus 5
#       LG phone
#       LG smart phone
#       LG smartphone
#       LG mobilephone
#       LG cell phone
#       LG cellphone
# LG - LG Other Phones - includeTerms.txt
#       LG phone
#       LG smart phone
#       LG smartphone
#       LG mobilephone
#       LG cell phone
#       LG cellphone
# LG - LG Other Phones - contextTerms.txt
# LG - LG Other Phones - excludeTerms.txt
#       lg g flex
#       lg g pro
#       lg g2
#       lg g3
#       lg l70
#       lg nexus 5
#       lg optimus
# Micromax - Micromas Bolt - includeTerms.txt
#       micromax a068
#       micromax a069
#       micromax a075
#       micromax a089
#       micromax a24
#       micromax a26
#       micromax a28
#       micromax a35
#       micromax a36
#       micromax a37
#       micromax a37b
#       micromax a46
#       micromax a47
#       micromax a58
#       micromax a59
#       micromax a61
#       micromax a62
#       micromax a69
#       micromax a71
#       micromax bolt
# Micromax - Micromas Bolt - contextTerms.txt
# Micromax - Micromas Bolt - excludeTerms.txt
#       micromax eg116
#       micromax elanza
#       micromax hd
#       micromax mini
#       micromax power
#       micromax smart phone
#       micromax smartphone
#       micromax a119
#       micromax a93
#       micromax a96
#       micromax canvas
#       micromax xl
#       micromax doodle
#       micromax doodle.*
#       micromax a177
#       micromax a77
#       micromax juice
#       micromax mad
#       micromax mad.*
#       micromax ninja
#       micromax ninja\s\d
#       micromax cellphone
#       micromax mobilephones
#       micromax phone
#       micromax duet
#       micromax eg111
#       micromax turbo
# Micromax - Micromax Canvas - includeTerms.txt
#       micromax xl
#       micromax a119
#       micromax a93
#       micromax a96
#       micromax canvas
#       micromax duet
#       micromax eg111
#       micromax eg116
#       micromax elanza
#       micromax hd
#       micromax mini
#       micromax power
#       micromax turbo
# Micromax - Micromax Canvas - contextTerms.txt
# Micromax - Micromax Canvas - excludeTerms.txt
#       micromax a068
#       micromax a069
#       micromax a075
#       micromax a089
#       micromax a24
#       micromax a26
#       micromax a28
#       micromax a35
#       micromax a36
#       micromax a37
#       micromax a37b
#       micromax a46
#       micromax a47
#       micromax a58
#       micromax a59
#       micromax a61
#       micromax a62
#       micromax a69
#       micromax a71
#       micromax bolt
#       micromax doodle
#       micromax doodle.*
#       micromax a177
#       micromax a77
#       micromax juice
#       micromax mad
#       micromax mad.*
#       micromax ninja
#       micromax ninja\s\d
#       micromax cellphone
#       micromax mobilephones
#       micromax phone
#       micromax smart phone
#       micromax smartphone
# Micromax - Micromax Doodle - includeTerms.txt
#       Micromax Doodle
#       micromax doodle.*
# Micromax - Micromax Doodle - contextTerms.txt
# Micromax - Micromax Doodle - excludeTerms.txt
#       micromax a068
#       micromax a069
#       micromax a075
#       micromax a089
#       micromax a24
#       micromax a26
#       micromax a28
#       micromax a35
#       micromax a36
#       micromax a37
#       micromax a37b
#       micromax a46
#       micromax a47
#       micromax a58
#       micromax a59
#       micromax a61
#       micromax a62
#       micromax a69
#       micromax a71
#       micromax bolt
#       micromax a119
#       micromax a93
#       micromax a96
#       micromax canvas
#       micromax duet
#       micromax eg111
#       micromax eg116
#       micromax elanza
#       micromax hd
#       micromax mini
#       micromax power
#       micromax turbo
#       micromax xl
#       micromax a177
#       micromax a77
#       micromax juice
#       micromax mad
#       micromax mad.*
#       micromax ninja
#       micromax ninja\s\d
#       micromax cellphone
#       micromax mobilephones
#       micromax phone
#       micromax smart phone
#       micromax smartphone
# Micromax - Micromax Juice - includeTerms.txt
#  micromax a177
#       micromax a77
#       micromax juice
# Micromax - Micromax Juice - contextTerms.txt
# Micromax - Micromax Juice - excludeTerms.txt
#       micromax a068
#       micromax a069
#       micromax a075
#       micromax a089
#       micromax a24
#       micromax a26
#       micromax a28
#       micromax a35
#       micromax a36
#       micromax a37
#       micromax a37b
#       micromax a46
#       micromax a47
#       micromax a58
#       micromax a59
#       micromax a61
#       micromax a62
#       micromax a69
#       micromax a71
#       micromax bolt
#       micromax a119
#       micromax a93
#       micromax a96
#       micromax canvas
#       micromax duet
#       micromax eg111
#       micromax eg116
#       micromax elanza
#       micromax hd
#       micromax mini
#       micromax power
#       micromax turbo
#       micromax xl
#       micromax doodle
#       micromax doodle.*
#       micromax mad
#       micromax mad.*
#       micromax ninja
#       micromax ninja\s\d
#       micromax cellphone
#       micromax mobilephones
#       micromax phone
#       micromax smart phone
#       micromax smartphone
# Micromax - Micromax Mad - includeTerms.txt
#       Micromax Mad
#       micromax Mad.*
# Micromax - Micromax Mad - contextTerms.txt
# Micromax - Micromax Mad - excludeTerms.txt
#       micromax a068
#       micromax a069
#       micromax a075
#       micromax a089
#       micromax a24
#       micromax a26
#       micromax a28
#       micromax a35
#       micromax a36
#       micromax a37
#       micromax a37b
#       micromax a46
#       micromax a47
#       micromax a58
#       micromax a59
#       micromax a61
#       micromax a62
#       micromax a69
#       micromax a71
#       micromax bolt
#       micromax a119
#       micromax a93
#       micromax a96
#       micromax canvas
#       micromax duet
#       micromax eg111
#       micromax eg116
#       micromax elanza
#       micromax hd
#       micromax mini
#       micromax power
#       micromax turbo
#       micromax xl
#       micromax doodle
#       micromax doodle.*
#       micromax a177
#       micromax a77
#       micromax juice
#       micromax ninja
#       micromax ninja\s\d
#       micromax cellphone
#       micromax mobilephones
#       micromax phone
#       micromax smart phone
#       micromax smartphone
# Micromax - Micromax Ninja - includeTerms.txt
#       Micromax Ninja
#       Micromax Ninja.*
# Micromax - Micromax Ninja - contextTerms.txt
# Micromax - Micromax Ninja - excludeTerms.txt
#       micromax a068
#       micromax a069
#       micromax a075
#       micromax a089
#       micromax a24
#       micromax a26
#       micromax a28
#       micromax a35
#       micromax a36
#       micromax a37
#       micromax a37b
#       micromax a46
#       micromax a47
#       micromax a58
#       micromax a59
#       micromax a61
#       micromax a62
#       micromax a69
#       micromax a71
#       micromax bolt
#       micromax a119
#       micromax a93
#       micromax a96
#       micromax canvas
#       micromax duet
#       micromax eg111
#       micromax eg116
#       micromax elanza
#       micromax hd
#       micromax mini
#       micromax power
#       micromax turbo
#       micromax xl
#       micromax doodle
#       micromax doodle.*
#       micromax a177
#       micromax a77
#       micromax juice
#       micromax mad
#       micromax mad.*
#       micromax cellphone
#       micromax mobilephones
#       micromax phone
#       micromax smart phone
#       micromax smartphone
# Micromax - Micromax Other Phones - includeTerms.txt
#       micromax cellphone
#       micromax mobilephones
#       micromax phone
#       micromax smart phone
#       micromax smartphone
# Micromax - Micromax Other Phones - contextTerms.txt
# Micromax - Micromax Other Phones - excludeTerms.txt
#       micromax a068
#       micromax a069
#       micromax a075
#       micromax a089
#       micromax a24
#       micromax a26
#       micromax a28
#       micromax a35
#       micromax a36
#       micromax a37
#       micromax a37b
#       micromax a46
#       micromax a47
#       micromax a58
#       micromax a59
#       micromax a61
#       micromax a62
#       micromax a69
#       micromax a71
#       micromax bolt
#       micromax a119
#       micromax a93
#       micromax a96
#       micromax canvas
#       micromax duet
#       micromax eg111
#       micromax eg116
#       micromax elanza
#       micromax hd
#       micromax mini
#       micromax power
#       micromax turbo
#       micromax xl
#       micromax doodle
#       micromax doodle.*
#       micromax a177
#       micromax a77
#       micromax juice
#       micromax mad
#       micromax mad.*
#       micromax ninja
#       micromax ninja\s\d
# Mobile features - Accessories - includeTerms.txt
#       cover for
#       case for.{0,4}(device|phone)
#       stylus
#       case
#       cover
#       acessories
#       Dot view
#       Dotview
#       power (bank.?|package.?)
#       cable.?
#       protector
#       stylus pen
#       charger.?
#       car mount.*
#       (wallpaper.?|sleeve.?|case.?|casing.?|cover.?) .{0,13}phone.?
#       accessories
#       accessory
#       phone.?.{0,13}(wallpaper.?|sleeve.?|case.?|casing.?|cover.?)
# Mobile features - Accessories - contextTerms.txt
# Mobile features - Accessories - excludeTerms.txt
#       arphones
#       headphones
#       headset
# Mobile features - Audio  Video - includeTerms.txt
#       earphone
#       headphone
#       sound
#       sound quality
#       speaker
#       video
#       imaging
#       audio
#       headset
# Mobile features - Audio  Video - contextTerms.txt
# Mobile features - Audio  Video - excludeTerms.txt
#       notebook
#       laptop
#       computer
#       CD player
#       OS
#       transcoder
#       voice recorder
#       flat screen
#       plasma tv
#       tablet
#       bluetooth speaker
#       turntable
#       home theater
#       hdtv
#       computer
#       promotional video
#       promotion video
#       Youtube
#       walkman
#       tv
#       sound system
#       sound forge
#       movie studio
#       sound dock
# Mobile features - Availability - includeTerms.txt
#       back order.*
#       unavailab.*
#       pre-order.*
#       release date.?
#       availability
#       out of stock
#       on order.*
#       shortage
#       preorder.*
#       order status
#       until|up to
#       htc ship out to retailers
#       cancel my order
#       back order.*
#       preorder.*
#       to arrive
# Mobile features - Availability - contextTerms.txt
# Mobile features - Availability - excludeTerms.txt
#       food
#       restaurant
#       hdtv
#       tv
#       home theater
# Mobile features - Battery - includeTerms.txt
#       battery time
#       battery health
#       drain
#       battery life
#       Charging
#       charged
#       discharging
#       battery drain
#       discharge
#       discharged
# Mobile features - Battery - contextTerms.txt
#       battery
# Mobile features - Battery - excludeTerms.txt
#       macbook
#       blackberry
#       ipad
#       notebook
#       car
#       vehicle
#       laptop
#       computer
#       mac
#       walkman
# Mobile features - Build Quality - includeTerms.txt
#  sturdy
#       water resist.*
#       drop test.*
#       water ressistance
#       dust resistance
#       dust resistence
#       water resistence
#       dust resist.*
#       cracked screen
#       shattered screen
#       peeled cover
#       build quality
#       durability
#       drop test
# Mobile features - Build Quality - contextTerms.txt
# Mobile features - Build Quality - excludeTerms.txt
#       economics
#       vehicle
#       car
#       recorder
#       tv
#       hdtv
#       led monitor
#       led screen
#       lcd
# Mobile features - Camera - includeTerms.txt
#       Camera
#       photo.*
#       blurry
#       picture quality
#       photo quality
#       resolution
#       low res.*
#       megapixel.*
#       Pixel.?
#       mega-pixel.*
#       Uitra-pixel
#       shooter
#       len
#       exposure setting
#       lens
#       ultra-pixel
#       autofoc.*
#       hi-def.*
#       LED-flash
#       1080p
#       \dMP
#       \d\dMP
#       resolution
#       Otter box
#       Panorama.?
#       shutter
#       mp\\d
#       HDR
#       Dual Capture
#       AF
#       auto-focus
#       auto focus
#       image stabilization
#       burst mode
# Mobile features - Camera - contextTerms.txt
# Mobile features - Camera - excludeTerms.txt
#       tv
#       hdtv
#       lcd screen
#       home entertainment system
#       home theater system
#       printer
#       canon
#       tv
#       hdtv
# Mobile features - Connectivity - includeTerms.txt
#       DLNA
#       USB
#       HDMI
#       GPS
#       syn.*
#       Connect.*
#       network.*
#       make.? sharing
#       file shar.*
#       (share.?|sharing) (music|file.*|data)
#       Airplane mode
#       Bluetooth
#       MMS
#       Messaging
#       SMS
#       Band (4|IV|V|5)
#       VoLTE
#       4g
#       5g
#       3g
#       detect.*
#       hook
#       Connectivity
#       Mbps.*
#       LTE
#       NFC.?
#       (upload|download) speed.?
#       disconnect.*
#       broadcast.*
#       casting
#       signal.?
#       CDMA
#       GSM
#       HSPA+
#       hotspot.*
#       tether.*
#       wifi
#       wireless
#       Wi-Fi
#       connectivity
# Mobile features - Connectivity - contextTerms.txt
# Mobile features - Connectivity - excludeTerms.txt
#       stereo
#       keyboard
#       camera
#       mouse
#       printer
#       headphone
#       headset
#       kindle
#       ebook
#       disc player
#       CD palyer
#       theater system
#       entertainment system
#       flat screen
#       tv
#       hdtv
#       earphone
# Mobile features - Design Features - includeTerms.txt
#       waterproo.*
#       new technolog.*
#       internals
#       repackag.*
#       design
#       trim.*
#       bullet.?
#       component.?
#       power button.?
#       (thumbprint |fingerprint) lock
#       construction
#       material.?
#       (their |the) build
#       metal .{0,10}cas.*
#       metalic
#       plastic.*
#       polycarbonate
#       rounded edge.?
#       round edge.?
#       Aesthetic
#       innovat.*
#       dual sim
#       dualsim
#       dual-sim
#       volume control.?
#       metal gray
#       back cover
#       RAM
#       Button.?
#       integrat.*
#       dock.*
#       Schematic.?
#       the look
#       (fantastic|excellent|best|great) phone
#       crafted
#       handset
#       clunky
#       dimension.?
#       Rectangular
#       Fits into (my)? pocket
#       flat
#       thin
#       (look.?|looked) .{0,4}like
#       look.{0,1}alike
#       (Device |body|craft.*|unibody|Case|handset) .{06} quality
#       crafted
#       body
#       unibody
#       chassis
#       scaling down
#       polycarbonate
#       biometric
#       heart rate sensor
#       heart rate monitor
#       fingerprint (reader|sensor|scanner)?
#       scans finger.*
#       water pro.*
#       dust pro.*
#       finger print (reader|sensor|scanner)?
#       water resistance
#       underwater for
#       keyboard.?
#       aluminum
#       built
#       finish
#       finishing
#       full.? metal.*
#       exterior
#       IMEI
#       latest tech.*
#       product.? satisfaction
#       feature-pack.*
# Mobile features - Design Features - contextTerms.txt
# Mobile features - Design Features - excludeTerms.txt
# Mobile features - Form Factor - includeTerms.txt
#       Size
#       not big.*
#       physical (size.?| footprint)
#       size.? of
#       the size.?
#       slide
#       heavier
#       heavy
#       lighter (weight)?
#       it look.*
#       it's look.*
#       (same|similar|smaller | larger) .{0,2}size.?
#       (sized|huge|big|small|bigger|smaller|biggest) .{0,6}(size.?|device.?|phone.*|handset.?)
#       (too|device.?|phone.*|handset.?) .{0,6}(huge|big|small)
#       big version
#       surface area
#       size and
#       screen size.?
#       lightweight
#       device size.?
#       big phone.?
#       .*inch display.?
#       large.? phone.?
#       like .{0,3}brick.?
#       Weight
#       bigger version
#       Dimension.?
#       form factor.?
#       formfactor
#       nice and big
# Mobile features - Form Factor - contextTerms.txt
# Mobile features - Form Factor - excludeTerms.txt
#       dtv
#       laptop
#       notebook
#       lightweight
#       lens
#       turntable
#       tv
#       clothes
#       screen
#       garment
#       headphones
#       headset
#       game
#       weight gain
#       health
#       walkman
#       camera
#       home entertainment
#       home theater
#       playstation
#       charger
#       battery
#       character
#       tree
#       car
#       vehicle
#       weight loss
#       logic pro
#       washer
#       pens
#       hotel
#       apple-icon
#       grill top
#       lose weight
#       computer
# Mobile features - Performance or HW Spec - includeTerms.txt
#       fast phone
#       faster phone
#       quad-core.?
#       dual core.?
#       quad core.?
#       dual-core.?
#       performed
#       processing speed
#       specs
#       specification.?
#       electronic.?
#       GPU
#       cpu.?
#       (multi.*|dual|quad) .{0,2}core.?
#       processor.?
#       Qualcomm
#       processing
#       (the|it) .{02}fast.*
#       Snapdragon
#       device .{06}(crawl.*|slow.*|fast)
#       as fast as
# Mobile features - Performance or HW Spec - contextTerms.txt
# Mobile features - Performance or HW Spec - excludeTerms.txt
#       laptop
#       notebook
#       computer
#       charger
#       recorder
#       cable
#       camera
#       cord
#       printer
#       monitor
#       filmmaker
#       sound
#       speaker
#       tv
#       hdtv
# Mobile features - Price - includeTerms.txt
#       cost
#       afford
#       break the bank
#       budget
#       cheap
#       it.? worth
#       not .{0,6}(costly|expensive|cheap)
#       pay for
#       paying my
#       value for money
#       worth (it | the)
#       worth while
#       worthwhile
#       price
#       shelling out
#       shell out
#       costly
#       expensive
#       overpriced
# Mobile features - Price - contextTerms.txt
# Mobile features - Price - excludeTerms.txt
#       monitor
#       computer
#       laptop
#       notebook
#       tv
#       hdtv
#       camera
#       DVD recorder
#       CD player
#       CD recorder
# Mobile features - Screen - includeTerms.txt
#       UHD
#       LCD.*
#       dual-LED
#       scrn
#       high res display.?
#       colour replication
#       color replication
#       resolution screen
#       HD display
#       lcd
#       .*ppi
#       1080p
#       SoLux
#       picture quality
#       pixels per inch
#       viewing experience.?
#       screen resolution
#       brightness
#       AMOLED
#       resolution
#       backlight
#       bright.*
#       display
#       resolution.?
#       .*screen.?
#       inch.*
#       display
#       ppi
#       .*in display.?
#       curved screen.?
#       res screen
# Mobile features - Screen - contextTerms.txt
# Mobile features - Screen - excludeTerms.txt
#       TV
#       HDTV
#       computer
#       laptop
#       notebook
#       camera
#       monitor
#       plasma
#       lcd panel
#       projector
#       theater
#       home theater
#       disc player
#       camcorder
#       refrigerator
#       range
#       stove
#       washer
#       kindle
# Mobile features - Service- Customer Support - includeTerms.txt
#  support center
#       maintenance.?
#       recall.*
#       fix
#       froze.?
#       warrant.*
#       malfunction.*
#       died on me
#       restor.*
#       (recent|latest |new|newest|newer|current|this) version.?
#       (operational}operation|operating) hour.?
#       How do I fix.?
#       (repair|call|Service) center.?
#       app store.?
#       application Store
#       customer agent
#       customer center
#       customer centre
#       Customer Service
#       Customer Services
#       (HTC|apple|samsung|nokia|LG|sony|micromax|karbonn) .{0,10}(service.?|support|center.?|centre.?)
#       SERVICE CENT.*
#       customer care
#       after (sale.?|purchase)
#       replace.? .{0,3}screen.?
#       Help Needed
#       warrenty
#       satisfactory resolution
#       issue.? resolution
#       resolution .{0,8}issue.*
#       (for|to) .{0,2}(repair.*|fixed)
#       repair center
#       tech support
#       technical support
#       technician.?
#       (apple|repair|call|Service) Centre.?
#       help desk.?
#       helpdesk.?
#       (apple|technical|tech|device |official|withdraw| withdrawed|withdrew |customer) supp.*
#       screen replac.*
#       official reseller
#       official support
#       service center
#       service centre
#       commit to
#       warranty
#       (change.?|update.?) .{0,2}(password|id)
#       user guide.?
#       resolve.? .{0,6}(problem.?|issue.*|situation.?)
#       (client.?|customer) service.?
#       (stability|support) issue.?
#       developer edition.?
#       error (state.?|message.?)
#       to be released
#       customer support
#       bad service
# Mobile features - Service- Customer Support - contextTerms.txt
# Mobile features - Service- Customer Support - excludeTerms.txt
# Mobile features - Service- Help need - includeTerms.txt
#       can (anyone|anybodysomeone|somebody) .{0,6}(help|tell|help|advise)
#       help me
#       Help Needed
#       Help!
#       Help!!
#       please help.?
#       (have|having) .{0,2}(issue.*|trouble.*|problem.*)
#       trying to figure out
#       need help
#       what (should|do|must|shall) I do
#       How i can do that
#       where can I go
#       how it works
#       experienced problem
#       not able to use
#       tell me why
#       any clue
#       how can I
#       what to do
#       how to solve
#       how do I
#       need help
#       what I can do
#       have question
#       unable to
#       any help
# Mobile features - Service- Help need - contextTerms.txt
# Mobile features - Service- Help need - excludeTerms.txt
# Mobile features - Software - includeTerms.txt
#       kernel
#       Gingerbread
#       Jelly Bean
#       KitKat
#       os
#       jailbreak
#       jailbroke
#       Bloatware
#       WhatsApp
#       Postagram
#       washboard
#       tumblr
#       instagram
#       iTunes
#       apps
#       hboot
#       upgrade
#       update to the latest
#       how to update
#       release
#       upgraded
#       get update
#       operating system
#       jailbreaking
#       jailbroken
#       bootloader
#       rom
#       IOS
#       Sense 6
#       downgrade
#       bug
#       Fixes
#       patch.*
#       downgraded
#       updates
#       beta
# Mobile features - Software - contextTerms.txt
#       software
# Mobile features - Software - excludeTerms.txt
# Mobile features - Storage - includeTerms.txt
#       Capacity
#       (16|32|64).{0,2}GB
#       data safety
#       data security
#       storage
#       disk storage
#       data capacity
# Mobile features - Storage - contextTerms.txt
# Mobile features - Storage - excludeTerms.txt
# Mobile features - Usability - includeTerms.txt
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-98-2eb48354264e> in <module>()
#      49                 for m in terms:
#      50                     print "     ",m
# ---> 51                     writer.writerow(m)
#      52
#      53
#
# UnicodeEncodeError: 'ascii' codec can't encode character u'\xe9' in position 0: ordinal not in range(128)
#       easy to use
#       (.*phone| usage|cell | mobile| | htc|my|better|refined | fluid | smooth | better | worst | best | great| lousy | bad | good | daily | general | overall | entire |personal|own) .{0,6}experience.?
#       response to touch
#       responsive.*
#       stylus
#       One-Hand Use
#       1 hand.*
#       one handed use
#       one hand
#       one-handed
#       one handed operation
#       interface
#       UI
#       gui
#       navigation
#       keypad.?
#       keyboard.?
#       voice navigat.*
#       voice activat.*
#       faster access
#       fast access
#       usability
#       easy to handle
#       touch
#       multi-touch
#       User.? .{0,20}experience.?
#       (user|overall |refined) experience.?
#       unlock screen
#       usability
#       day-to-day experience
#       autocorrect
#       unlock phone
#       unlocking .{0,3}(phone|screen)
# Mobile features - Usability - contextTerms.txt
# Mobile features - Usability - excludeTerms.txt
# Nokia - Nokia ASHA - includeTerms.txt
#       nokia asha
#       nokiaasha
# Nokia - Nokia ASHA - contextTerms.txt
# Nokia - Nokia ASHA - excludeTerms.txt
#       lumia 930
#       Nokia Lumia
#       the lumia
#       lumia \d\d\d(\d)?
#       nokia phone
#       nokia smart phone
#       nokia smartphone
#       lumia 1020
#       lumia 1320
#       lumia 1520
#       lumia 510
#       lumia 520
#       lumia 610
#       lumia 620
#       lumia 625
#       lumia 635
#       lumia 710
#       lumia 720
#       lumia 800
#       lumia 820
#       lumia 900
#       lumia 920
#       lumia 925
#       nokia mobilephone
#       nokia mobile phone
#       nokia cellphone
#       nokia cell phone
# Nokia - Nokia Lumia - includeTerms.txt
#       lumia 1020
#       lumia 1320
#       lumia 1520
#       lumia 510
#       lumia 520
#       lumia 610
#       lumia 620
#       lumia 625
#       lumia 635
#       lumia 710
#       lumia 720
#       lumia 800
#       lumia 820
#       lumia 900
#       lumia 920
#       lumia 925
#       lumia 930
#       Nokia Lumia
#       the lumia
#       lumia \d\d\d(\d)?
# Nokia - Nokia Lumia - contextTerms.txt
# Nokia - Nokia Lumia - excludeTerms.txt
#       nokia asha
#       nokiaasha
#       nokia phone
#       nokia smart phone
#       nokia smartphone
#       nokia mobilephone
#       nokia mobile phone
#       nokia cellphone
#       nokia cell phone
# Nokia - Nokia Other Phones - includeTerms.txt
#       nokia phone
#       nokia smart phone
#       nokia smartphone
#       nokia mobilephone
#       nokia mobile phone
#       nokia cellphone
#       nokia cell phone
# Nokia - Nokia Other Phones - contextTerms.txt
# Nokia - Nokia Other Phones - excludeTerms.txt
#       lumia 625
#       lumia 635
#       lumia 710
#       lumia 720
#       lumia 800
#       lumia 820
#       lumia 900
#       lumia 920
#       lumia 925
#       lumia 930
#       nokia asha
#       nokiaasha
#       Nokia Lumia
#       the lumia
#       lumia \d\d\d(\d)?
#       lumia 1020
#       lumia 1320
#       lumia 1520
#       lumia 510
#       lumia 520
#       lumia 610
#       lumia 620
# Samsung - Samsung Galaxy S - includeTerms.txt
#       SamsungGalaxyS
#       Galaxy S.*
#       GalaxyS.*
#       samsung galaxy
#       S[1,9]
#       S(II|III|IV|V|VI) ; S (II|III|IV|V|VI)
#       GS[1,9]
# Samsung - Samsung Galaxy S - contextTerms.txt
# Samsung - Samsung Galaxy S - excludeTerms.txt
#       Samsung smartphone
#       Samsung mobilephone
#       Samsung phone
#       Samsung smart phone
#       Samsung mobile
#       Samsung Illusion
#       coupé
