# %% [markdown]
# # Authorize with Twitter

# %% [markdown]
# # Retrieve tweets related to search and store for analysis

# %%
# https://pypi.python.org/pypi/twitter
# https://dev.twitter.com/docs/api/1.1
# 


from twitter import *
import json

OAUTH_TOKEN = '29499583-TN805p7dPVvBnaBhU5ldegeQTx16JqYMaFM8AkzSo'
OAUTH_SECRET = 'dd4cSOXoruGfoykzlx6gHcSTIEQDuQkTsW4qobFyds'
CONSUMER_KEY = 'xLNSlDfsYDWoVDVlnUewog'
CONSUMER_SECRET = 'cysEIjDiZ29J81XbMpzXndE0s7cAL5lX7XygY4G80Qc'

# see "Authentication" section below for tokens and keys
t = Twitter(
            auth=OAuth(OAUTH_TOKEN, OAUTH_SECRET,
                       CONSUMER_KEY, CONSUMER_SECRET)
           )

# Get your "home" timeline
#t.statuses.home_timeline()
query = "#bigdata"
myCount = 1000
myStart = 1

# twitter search
r = t.search.tweets(q=query,count=myCount)
tweets = json.loads(json.dumps(r['statuses'], indent=1))
my_max_id = r['search_metadata']['max_id']

#write to file for review
tweets_data = 'C:/Projects/ipython/tweets.json'
f = open(tweets_data, 'w')
f.write(json.dumps(r, indent=2))
f.close()

for k in range(1,5): 
    try:
        next_results = r['search_metadata']['next_results']
        my_max_id = r['search_metadata']['max_id']
        #print my_max_id
        
    except KeyError, e: # No more results when next_results doesn't exist
        break
    
    r = t.search.tweets(q=query,count=myCount,max_id=my_max_id)
    tweets += json.loads(json.dumps(r['statuses'], indent=1))

from openpyxl import Workbook
wb = Workbook()
ws = wb.get_active_sheet()

dest_filename = 'C:/Projects/ipython/twitter.xlsx'#r'test_book.xlsx'

ws = wb.worksheets[0]

ws.title = "Twitter"

# create header
ws.cell('A1').value = 'TweetID'
ws.cell('B1').value = 'TweetDateTime'
ws.cell('C1').value = 'Author_ID'
ws.cell('D1').value = 'TweetText'
ws.cell('E1').value = 'RetweetCount'
ws.cell('F1').value = 'FavoriteCount'
ws.cell('G1').value = 'UserMentions'
ws.cell('H1').value = 'Hashtags'
ws.cell('I1').value = 'URLs'
ws.cell('J1').value = 'AuthorID'
ws.cell('K1').value = 'FollowersCount'
ws.cell('L1').value = 'FriendsCount'
ws.cell('M1').value = 'StatusesCount'
ws.cell('N1').value = 'UserLocation'
ws.cell('O1').value = 'Description'
ws.cell('P1').value = 'OriginalAuthorID'
ws.cell('Q1').value = 'OriginalTweetText'
ws.cell('R1').value = 'OriginalRetweetCount'
ws.cell('S1').value = 'OriginalFavoriteCount'

i = 2
for tweet in tweets:
    if 'id' in tweet: #'TweetID'
        ws.cell('%s%s'%('A', i)).value = tweet['id'] 
    else:
        ws.cell('%s%s'%('A', i)).value = "" 
    
    if 'created_at' in tweet: #'TweetDateTime'
        ws.cell('%s%s'%('B', i)).value = tweet['created_at'] 
    else:
        ws.cell('%s%s'%('B', i)).value = ""        
    
    if 'user' in tweet: #'Author_ID'
        ws.cell('%s%s'%('C', i)).value = tweet['user']['id'] 
    else:
        ws.cell('%s%s'%('C', i)).value = ""
        
    if 'text' in tweet: #'TweetText'
        ws.cell('%s%s'%('D', i)).value = tweet['text'] 
    else:
        ws.cell('%s%s'%('D', i)).value = ""
        
    if 'retweet_count' in tweet: #'RetweetCount'
        ws.cell('%s%s'%('E', i)).value = tweet['retweet_count'] 
    else:
        ws.cell('%s%s'%('E', i)).value = ""
        
    if 'favorite_count' in tweet: #'FavoriteCount'
        ws.cell('%s%s'%('F', i)).value = tweet['favorite_count'] 
    else:
        ws.cell('%s%s'%('F', i)).value = ""
        
    if 'entities' in tweet: #'UserMentions'
        if 'user_mentions' in tweet['entities']:
            mentions = ""
            for j in range(0,len(tweet['entities']['user_mentions'])):
                mentions = mentions + str(tweet['entities']['user_mentions'][j]['id']) + "|"
            ws.cell('%s%s'%('G', i)).value = mentions
    else:
        ws.cell('%s%s'%('G', i)).value = ""
        
    if 'entities' in tweet: #'Hashtags'
        ws.cell('%s%s'%('H', i)).value = tweet['entities']['hashtags'] 
    else:
        ws.cell('%s%s'%('H', i)).value = ""
        
    if 'entities' in tweet: #'URLs'
        if 'urls' in tweet['entities']:
            urls = ""
            for j in range(0,len(tweet['entities']['urls'])):
                urls = urls + tweet['entities']['urls'][j]['expanded_url'] + "|"
            ws.cell('%s%s'%('I', i)).value = urls 
    else:
        ws.cell('%s%s'%('I', i)).value = ""
        
    if 'user' in tweet: #'AuthorID'
        ws.cell('%s%s'%('J', i)).value = tweet['user']['id']
    else:
        ws.cell('%s%s'%('J', i)).value = ""
        
    if 'user' in tweet: #'FollowersCount'
        ws.cell('%s%s'%('K', i)).value = tweet['user']['followers_count'] 
    else:
        ws.cell('%s%s'%('K', i)).value = ""
        
    if 'user' in tweet: #'FriendsCount'
        ws.cell('%s%s'%('L', i)).value = tweet['user']['friends_count'] 
    else:
        ws.cell('%s%s'%('L', i)).value = ""
        
    if 'user' in tweet: #'StatusesCount'
        ws.cell('%s%s'%('M', i)).value = tweet['user']['statuses_count']
    else:
        ws.cell('%s%s'%('M', i)).value = ""
        
    if 'user' in tweet: #'UserLocation'
        ws.cell('%s%s'%('N', i)).value = tweet['user']['location']
    else:
        ws.cell('%s%s'%('N', i)).value = ""
        
    if 'user' in tweet: #'Description'
        ws.cell('%s%s'%('O', i)).value = tweet['user']['description'] 
    else:
        ws.cell('%s%s'%('O', i)).value = ""
        
    if 'retweeted_status' in tweet: #'OriginalAuthorID'
        ws.cell('%s%s'%('P', i)).value = tweet['retweeted_status']['user']['id'] 
    else:
        ws.cell('%s%s'%('P', i)).value = ""
        
    if 'retweeted_status' in tweet: #'OriginalTweetText'
        ws.cell('%s%s'%('Q', i)).value = tweet['retweeted_status']['text']
    else:
        ws.cell('%s%s'%('Q', i)).value = ""
        
    if 'retweeted_status' in tweet: #'OriginalRetweetCount'
        ws.cell('%s%s'%('R', i)).value = tweet['retweeted_status']['retweet_count']
    else:
        ws.cell('%s%s'%('R', i)).value = ""
        
    if 'retweeted_status' in tweet: #'Description'
        ws.cell('%s%s'%('S', i)).value = tweet['retweeted_status']['favorite_count'] 
    else:
        ws.cell('%s%s'%('S', i)).value = ""
        
    i += 1
   
wb.save(filename = dest_filename)

# %% [markdown]
# # Retrieve tweets and append new tweets to previously collected tweets

# %%
for _ in range(5): 
    try:
        next_results = search_results['search_metadata']['next_results']
    except KeyError, e: # No more results when next_results doesn't exist
        break

    kwargs = dict([ kv.split('=') for kv in next_results[1:].split("&") ]) # Create a dictionary from the query string params
    search_results = twitter_api.search.tweets(**kwargs)
    statuses += search_results['statuses']

# %%
# https://pypi.python.org/pypi/twitter
# https://dev.twitter.com/docs/api/1.1
# 


from twitter import *
import json

OAUTH_TOKEN = '29499583-TN805p7dPVvBnaBhU5ldegeQTx16JqYMaFM8AkzSo'
OAUTH_SECRET = 'dd4cSOXoruGfoykzlx6gHcSTIEQDuQkTsW4qobFyds'
CONSUMER_KEY = 'xLNSlDfsYDWoVDVlnUewog'
CONSUMER_SECRET = 'cysEIjDiZ29J81XbMpzXndE0s7cAL5lX7XygY4G80Qc'

# see "Authentication" section below for tokens and keys
t = Twitter(
            auth=OAuth(OAUTH_TOKEN, OAUTH_SECRET,
                       CONSUMER_KEY, CONSUMER_SECRET)
           )

# Get your "home" timeline
#t.statuses.home_timeline()

# twitter search
r = t.search.tweets(q="#bigdata")
tweet = json.loads(json.dumps(r, indent=1))

for status in tweet['statuses']:
    if 'text' in status:
        print status['text'] + "\n"
# Out:
# Big Pharma companies are learning lots about individuals without violating HIPAA. Concerned? #BigData #Healthcare http://t.co/RYRYuAWTvH
#
# RT @jpportron: #Orange #cloudcomputing #bigdata: nouveaux services, nouveaux enjeux compétences. Le CE #Orange Normandie Centre au #datacen…
#
# A great talk by #IBM's Inhi Suh on #BigData myths https://t.co/CzxU1sLjxp
#
# RT @iioannoulbs: Target Confirms Millions Of Customer Credit Cards Hacked Since Black Friday http://t.co/DhKpIRcROd #privacy #bigdata #acco…
#
# Emerging #Electricity Value Chain | #smartgrid #smartmeters #bigdata #ibm http://t.co/e1bmQfRBRs
#
# @Syncsort has found new life with what enterprises with legacy systems require for #Hadoop and #bigdata analytics http://t.co/rLEMEYxWDf
#
# RT @SolvingBacon: Science of Bacon intro slides available: http://t.co/t7weE8Fjt7 #data #datastrategy #Strategy #privacy  #bigdata
#
# Expectativas multimillonarias para #bigdata en los próximos 4 años http://t.co/SwpMtpP5cp
#
# RT @varonis: [Free eBook] 10 Insights on Enterprise Data:
#
# http://t.co/nJVtY8CHfc
#
# #bigdata #dataprotection #datagovernance http://t.co/…
#
# Science of Bacon intro slides available: http://t.co/t7weE8Fjt7 #data #datastrategy #Strategy #privacy  #bigdata
#
# #BigData to Drive Quality Patient Care and Outcomes in 2014 http://t.co/2tdgA8pTis
#
# RT @varonis: What was Snowden REALLY up to?
#
# http://t.co/oxAwsi72qj
#
# #snowden #nsa #bigdata #privacy
#
# @JustJon @parallelbranch is offering free courses to everyone  at http://t.co/Y1DRH2EB1t
# #oracle #sharepoint #bigdata #hadoop
#
# RT @albertg2g: .@jfvillena es curioso, todo el mundo tiene su propia forma de hablar de #BigData pero el uso de la metafora "piscina de dat…
#
# Checklist for managing growing IT workloads in your #bigdata environment: http://t.co/5SoVigBGzP via @CIOonline #BMCControlM

# %%
from twitter import *
import json

OAUTH_TOKEN = '29499583-TN805p7dPVvBnaBhU5ldegeQTx16JqYMaFM8AkzSo'
OAUTH_SECRET = 'dd4cSOXoruGfoykzlx6gHcSTIEQDuQkTsW4qobFyds'
CONSUMER_KEY = 'xLNSlDfsYDWoVDVlnUewog'
CONSUMER_SECRET = 'cysEIjDiZ29J81XbMpzXndE0s7cAL5lX7XygY4G80Qc'

# see "Authentication" section below for tokens and keys
t = Twitter(
            auth=OAuth(OAUTH_TOKEN, OAUTH_SECRET,
                       CONSUMER_KEY, CONSUMER_SECRET)
           )

# Get your "home" timeline
#t.statuses.home_timeline()
query = "#bigdata"
myCount = 10
myStart = 1

# twitter search
r = t.search.tweets(q=query,count=myCount)
tweets = json.loads(json.dumps(r['statuses'], indent=1))
my_max_id = r['search_metadata']['max_id']
print r['search_metadata']['next_results']

"""
#write to file for review
tweets_data = 'C:/Projects/ipython/tweets.json'
f = open(tweets_data, 'w')
f.write(json.dumps(r, indent=2))
f.close()
"""

for k in range(0,5): 
    try:
        next_results = r['search_metadata']['next_results']
        my_max_id2 = r['search_metadata']['max_id']
        print next_results
        
    except KeyError, e: # No more results when next_results doesn't exist
        break
    
    r = t.search.tweets(q=query,count=myCount,max_id=my_max_id2-1)
    tweets += json.loads(json.dumps(r['statuses'], indent=1))
# Out:
# ?max_id=414097079624282111&q=%23bigdata&count=10&include_entities=1
# ?max_id=414097079624282111&q=%23bigdata&count=10&include_entities=1
# ?max_id=414097063723282431&q=%23bigdata&count=10&include_entities=1
# ?max_id=414097063723282431&q=%23bigdata&count=10&include_entities=1
# ?max_id=414097063723282431&q=%23bigdata&count=10&include_entities=1
# ?max_id=414097063723282431&q=%23bigdata&count=10&include_entities=1

# %% [markdown]
# # Capture Streaming Data using Tweepy

# %% [raw]
# http://nbviewer.ipython.org/github/raynach/hse-twitter/blob/master/docs/Collecting%20Twitter%20data%20from%20the%20API%20with%20Python.ipynb
#
# http://www.alex-hanna.com/tworkshops/lesson-7-mention-network-analysis/

# %%
import tweepy
from tweepy import StreamListener
import json, time, sys

class SListener(StreamListener):

    def __init__(self, api = None, fprefix = 'streamer'):
        self.api = api or API()
        self.counter = 0
        self.fprefix = fprefix
        self.output  = open('C:/Projects/ipython/data/' + fprefix + '.' 
                            + time.strftime('%Y%m%d-%H%M%S') + '.json', 'w')
        self.delout  = open('C:/Projects/ipython/data/delete.txt', 'a')

    def on_data(self, data):

        if  'in_reply_to_status' in data:
            self.on_status(data)
        elif 'delete' in data:
            delete = json.loads(data)['delete']['status']
            if self.on_delete(delete['id'], delete['user_id']) is False:
                return False
        elif 'limit' in data:
            if self.on_limit(json.loads(data)['limit']['track']) is False:
                return False
        elif 'warning' in data:
            warning = json.loads(data)['warnings']
            print warning['message']
            return false

    def on_status(self, status):
        self.output.write(status + "\n")

        self.counter += 1

        if self.counter >= 20000:
            self.output.close()
            self.output = open('C:/Projects/ipython/data/' + self.fprefix + '.' 
                               + time.strftime('%Y%m%d-%H%M%S') + '.json', 'w')
            self.counter = 0

        return

    def on_delete(self, status_id, user_id):
        self.delout.write( str(status_id) + "\n")
        return

    def on_limit(self, track):
        sys.stderr.write(track + "\n")
        return

    def on_error(self, status_code):
        sys.stderr.write('Error: ' + str(status_code) + "\n")
        return False

    def on_timeout(self):
        sys.stderr.write("Timeout, sleeping for 60 seconds...\n")
        time.sleep(60)
        return 

    
    import time, tweepy, sys

## auth. 
## TK: Edit the username and password fields to authenticate from Twitter.
#username = ''
#password = ''
#auth     = tweepy.auth.BasicAuthHandler(username, password)


## Eventually you'll need to use OAuth. Here's the code for it here.
## You can learn more about OAuth here: https://dev.twitter.com/docs/auth/oauth
#OAUTH_TOKEN = '29499583-TN805p7dPVvBnaBhU5ldegeQTx16JqYMaFM8AkzSo'
#OAUTH_SECRET = 'dd4cSOXoruGfoykzlx6gHcSTIEQDuQkTsW4qobFyds'
#CONSUMER_KEY = 'xLNSlDfsYDWoVDVlnUewog'
#CONSUMER_SECRET = 'cysEIjDiZ29J81XbMpzXndE0s7cAL5lX7XygY4G80Qc'
consumer_key        = "xLNSlDfsYDWoVDVlnUewog"
consumer_secret     = "cysEIjDiZ29J81XbMpzXndE0s7cAL5lX7XygY4G80Qc"
access_token        = "29499583-TN805p7dPVvBnaBhU5ldegeQTx16JqYMaFM8AkzSo"
access_token_secret = "dd4cSOXoruGfoykzlx6gHcSTIEQDuQkTsW4qobFyds"

# OAuth process, using the keys and tokens
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

def main( mode = 1 ):
    # track is for terms to be tracked
    # follow is a list of userid's that you want to get all of their statuses
    # total volume of whatever you pull back is limited to 1% of the overall twitter volume at that moment
    #
    #track  = ['#bigdata','#analytics','#socbiz','#datamining','ValaAfshar','burkepowers','KirkDBorne','gwenthomasdgi','billfranksga','ConstellationRG','DeloitteBA','iianalytics','EdwardTufte','Doug_Laney','johnelder4','davidloshin','DanVesset','isaiahgoodall','usamaf','bevelson','mikeferguson1','Freakalytics','predictanalytic','howarddresner','ROIRevolution','ocdqblog','jakeporway','brunoaziza','btemkin','beyondthearc','drewconway','ariegoldshlager','deanabb','SethGrimes','PatrickMeier','jilldyche','Claudia_Imhoff','weckerson','fivethirtyeight','mitsmr','avinash','1to1Media','donalddotfarmer','AlanSee','rwang0','DataMiningBlog','mgualtieri','JeffJonas','tdav','jamet123','mcristia','jowyang','briansolis','@merv','ISpeakAnalytics','KenexaSocial','ted_friedman','databaseguru','steve_dine','IBMSPSS','marksmithvr','INFORMS','infomgmt','kdnuggets','jeffreyfkelly','bigdata','ventanaresearch','ColinJWhite','SmarterPlanet','SmartDataCo','dataqualitypro','wiseanalytics','ibmbizanalytics','analyticbridge','forrester']
    track  = ['#bigdata','#analytics','#socbiz','#datamining']
    follow = [534563976,14072398,15822273,108286674,20167623,485055264,18503214,39600478,14562685,339653183,14060372,192579441,135945569,39413322,309425789,38670441,250103509,107376471,23204397,10915042,19573968,7617702,16871339,16948477,97348240,20748873,119802433,62316970,23230622,250257799,5676402,10781952,16895951,1585,15257533,64368500,14457688,16689471,14847675,18068926,92116069,22059787,38427411,25136114,11581462,894057794,317005231,9526012,16534327,42079656,77449588,18638602,10565902,237413764,14133436,17817175,113022733,10748252,805323,259725229,23242773,33042238,16598272,15160685,14065040,14191961,16693331,803694,41788528,39804979,43878033,3709051,243465644,193030139,194081605,107938429,14184076,21393134,15481072,27549343,591248843,79275123,168282354,294405972,397450344,15612251,139169346,17850251,2981431,17204373,63875612,26412800,15298751,38790830,14746910,22238542,89440968,16688845,246346708,7480172,260909325,39345049,18318677,14093970,365453693,22631958,11344912,198483889,14065217,227423290,19825996,4921851,705287821,34155148,263830118,260582890,17043455,21922529,5727392,19123248,18914917,13860052,15344094,63109065,15374525,35186545,141752902,15106068,14596096,14994269,22773313,29649822,134908142,14761966,41381572,21566520,13455092,20453726,118030412,9965842,90478485,16816193,582199192,15336340,112717095,53257764,218155014,14066062,217488696,23114136]
            
    listen = SListener(api, 'test')
    stream = tweepy.Stream(auth, listen)

    print "Streaming started on %s users and %s keywords..." % (len(track), len(follow))

    try: 
        stream.filter(track = track, follow = follow)
        #stream.sample()
    except:
        print "We had an unknown error! Script halted."
        stream.disconnect()

if __name__ == '__main__':
    main()
# Out:
# Streaming started on 4 users and 150 keywords...
# We had an unknown error! Script halted.

# %% [markdown]
# # Pagination through user timeline

# %%
import tweepy
from tweepy import StreamListener
import json, time, sys

consumer_key        = "xLNSlDfsYDWoVDVlnUewog"
consumer_secret     = "cysEIjDiZ29J81XbMpzXndE0s7cAL5lX7XygY4G80Qc"
access_token        = "29499583-TN805p7dPVvBnaBhU5ldegeQTx16JqYMaFM8AkzSo"
access_token_secret = "dd4cSOXoruGfoykzlx6gHcSTIEQDuQkTsW4qobFyds"

# OAuth process, using the keys and tokens
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

for page in tweepy.Cursor(api.user_timeline).pages(3):
        for item in page:
                print item.text
# Out:
# RT @choccytracy: RT @ValaAfshar: Your brand is what people say about you when you're not in the room. The web is the room and it's social. …
# RT @rwang0: "In a startup the purpose of analytics is to iterate product/market fit before the money runs out" @blake #sxswv2v #reachhacking
# MT @SethGrimes: 'Should we be replacing “r” with “e”, identifying Influencees and not Influencers?' asks @Marie_Wallace #socbiz
# RT @kdnuggets: World Top "Data" Scientists before "Data Science": Shannon, Tukey, Kolmogorov, Markov,Tufte, (Turing?) http://t.co/iZrpm7B7PU
# RT @HarvardBiz: Don't Make Decisions, Orchestrate Them http://t.co/Q13oH5f08c #analytics #decisionmgt
# RT @kdnuggets: Twitter analytics cheat sheet, tips, and tactics http://t.co/tuafjXNV6B
# "Numbers have an important story to tell.  They rely on you to give them a clear and convincing voice." -Stephen Few #analytics #decisionmgt
# Do you model feedback loops in biz decisions? "Arctic ice grows darker" http://t.co/bsaj4Wl5y8 @newscientist #decisionmgt #analytics
# #Analytics finds the strike zone. "Why productive people stick to their strike zone" http://t.co/DYfdIIqmN7 @FastCompany #decisionmgt
# IBM brought together the latest and best thinkers on segmentation. http://t.co/E1vKbRdXe4 @ibmbigdata #cxo #analytics #socbiz
# "Never confuse motion with action." -Benjamin Franklin #analytics #decisionmgt #socbiz
# RT @kirkdborne: From Academic PhD to #DataScientist: 5 Tips from @DouglasMason10 for Making the Transition. http://t.co/IGhWgG5FPP
# Actionable? "Tesla Model S vs Toyota Prius Interests, Datamining Shows Differences" http://t.co/IfdThayUjV @greenoptimistic #analytics
# Actionable? "Tesla Model S vs Toyota Prius Interests, Datamining Shows Differences" http://t.co/0tR14zyE1x @greenoptimistic #analytics
# Actionable? "Tesla Model S vs Toyota Prius Interests, Datamining Shows Differences" http://t.co/Y2E3ws0DQC @greenoptimistic #analytics
# Is there evidence of backlash against generosity in #sm? "When Good Deeds Are Punished" http://t.co/sWzpKAbjDy @freakonomics #socbiz
# Technical, but good - Incorporate analytics properly. "Analytical Scorecard Development" http://t.co/oIchvHOgEd @roopamu #analytics #socbiz
# A worthy goal. Do we understand the causal direction? "The Impossible Quest for Happiness" http://t.co/D6emn2cowT @writenoreen #analytics
# Wish they'd teach this in school. "5 Tips to Crack an Analytics Interview" http://t.co/7ktPVvVGHY @jigsawacademy #analytics
# "Get the habit of analysis. In time, it will enable synthesis to become your habit of mind." -Frank Lloyd Wright #analytics
# "A point of view can be a dangerous luxury when substituted for insight and understanding." - Marshall McLuhan #analytics #decisionmgt
# "The Big Brand Theory: How Maersk Grew Social Media Influence in the Shipping Industry" http://t.co/6VWE5xEdMP @RicDragon #socbiz
# Decision context of any analytics "A Practitioner Speaks: Analytics and Decision Management" http://t.co/OCWRilBKEk @jamet123 #analytics
# What events do you prefer? "30 Meetings on Analytics, Big Data, Data Mining" http://t.co/7vsfsAnL4q @kdnuggets #analytics #bigdata #socbiz
# What non-tech ?'s do you ask? "89 job interview questions for data scientists" http://t.co/vCSx4Eoy0y @analyticbridge #analytics #bigdata
# Interesting BBC documentary "The Age of Big Data - BBC Documentary" http://t.co/mVGrlDfgcV  @kdnuggets #bigdata #analytics
# Good writeup explaining big data and analytics to my grandma "Mining big data" http://t.co/DFg65rf33N @presscitizen #bigdata #analytics
# IBM only one to get 5 stars "10 Enterprise Predictive Analytics Platforms Compared" http://t.co/xnhxYJQVy9 @kdnuggets @ibmbigdata #analytics
# Talented volunteers needed "How Big Data Can Help the Developing World Beat Poverty" http://t.co/NPPTNcZ1Gk @VanRijmenam #bigdata #analytics
# Can we do this with in meetings? "Teacher forces student to do math to unlock phone" http://t.co/ggi0mywNq9 @FryRsquared #mathfun
# Example of cavalier causality "That causal inference came out of nowhere" http://t.co/4W7LBCkm4p @simplystats #analytics
# Another way to predict crime before it happens "While You're Away, the Burglars Will Play" http://t.co/IdL6rmXpq9 @Beth_Schultz #analytics
# Who would have guessed the future of space travel "Crowd-Funding a Mission To Jupiter's Moons" http://t.co/sWZ6pW4ucp @slashdot #socbiz
# What do you do when you get non-intuitive results? "Do Baby Girls Cause Divorce?" http://t.co/H3MN0aKzKe @Freakonomics #analytics
# @TIBCOSpotfire Thanks for the RT. Keep up the good work that we all enjoy so much.
# @IBMbigdata Thanks for the RT. And thanks for the great information.
# How are you measuring success? "What are the best tools to measure social media influence?" http://t.co/ELgO5ZtWNZ @lilachbullock #socbiz
# Recruiting curiosity "Building An Analytics Dream Team" http://t.co/ACUVJkacaH @AllAnalytics @Beth_Schultz #analytics #socbiz
# Do you know your target audience this well? "STUDY: Venture Capital Influencer Insights" http://t.co/5t9otoVodq #ZenoVCstudy #socbiz
# Fail to plan..."Predictive analytics programs marred by poor planning, flawed models" http://t.co/2EIUidWof1 @BizAnalyticsTT #analytics
# Business needs to guide "Path on predictive analytics tools needs light from business beacons" http://t.co/JnK4VrZx1p #analytics #socbiz
# Text analytics gets you even better actions "How to Do a Social Media Competitive Analysis" http://t.co/Jesr6plAJY @socialcade #socbiz
# RT @Beth_Schultz "RT @metabrown312: Why IT Doesn’t “Get” Analytics (and how to make the first move in the right direction)  "...
# Proper analytics gets your message to your customer "Information Overload from Social Media" http://t.co/Z07bHRqRak #socbiz #analytics
# Unique aspects to big data issues "Today's Big Data is Not Yesterday's Big Data" http://t.co/C8uKsib8Kr @analyticbridge #bigdata
# Best thinking on segmentation from many authors. "Solving for Segmentation: Is Big Data "X"?" http://t.co/kvac8jd4g6 @ibmbigdata #analytics
# Great visualizations "Winning in Pharmaceutical Emerging Markets with Analytics" http://t.co/Pf6VayyrjT @TIBCOSpotfire #analytics
# Interesting new tools "Introducing New LinkedIn Company Page Analytics" http://t.co/t9w0AjEKX7 @linkedin #analytics #socbiz
# This really seems to capture #socbiz "Book Review: 5 Takeaways from Youtility by Jay Baer" http://t.co/BBO7fRsWzt @DebraWEllis
# I see these all the time "Common Misconceptions on Automating Decisions" http://t.co/vCiwiadsFU @jamet123 #decisionmgt #analytics
# Cross-channel optimization "How to Run a Successful Multi-Platform Hashtag Campaign" http://t.co/W56NPZydrE @WillAtSMF #socbiz
# 3 key competencies for #socbiz success "Are You on Board with Social Business?" http://t.co/EzrxUvpF4P @MJRomeriDDC
# Finding systemic problems "Data Mining for Underpayments Yields Millions for Health System" http://t.co/RLm5iBK39G #analytics
# Add cust journey map. RT @dreckbaerfrau: Learn the tricks of reputation management to increase customer satisfaction  http://t.co/cCUqjjBgH3
# RT @sniperanalytics: "Companies are better at collecting data about customers than they are at using it to service them".(Who can afford...
# @data_nerd @deanabb So, for you, what were key 2)??? experiences? For me, it was learning how to present technical to non-technical folks.
# @data_nerd Agreed, Data Scientist aren't created in College. Path is 1) school 2) ??? 3) big data job 4) profit. Good #bigdata talent rare.
# @data_nerd I mentor &amp; train analytics. Many of the best come from EDW #bigdata backgrounds. Soft skills most often lacking &amp; hard to train.
# Always asking better questions. RT @YvesMulkers Big Data Observations: The Science of Asking Questions http://t.co/FKIV8UvLmZ #analytics
# RT @Doug_Laney RT @sve_sic: Key soft skills of #datascientist: communication, collaboration, leadership, creativity, passion &amp; discipline

# %%
import tweepy
from tweepy import StreamListener
import json, time, sys

consumer_key        = "xLNSlDfsYDWoVDVlnUewog"
consumer_secret     = "cysEIjDiZ29J81XbMpzXndE0s7cAL5lX7XygY4G80Qc"
access_token        = "29499583-TN805p7dPVvBnaBhU5ldegeQTx16JqYMaFM8AkzSo"
access_token_secret = "dd4cSOXoruGfoykzlx6gHcSTIEQDuQkTsW4qobFyds"


if __name__ == '__main__':
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_token_secret)
    
    api = tweepy.API([auth], # support for multiple authentication handlers
                     retry_count=3, retry_delay=5, retry_errors=set([401, 404, 500, 503]), # retry 3 times with 5 seconds delay when getting these error codes. For more details see https://dev.twitter.com/docs/error-codes-responses
                     monitor_rate_limit=True, wait_on_rate_limit=True # monitor remaining calls and block until replenished
                    )
    
    query = 'cupcake OR donut'
    page_count = 0
    for tweets in tweepy.Cursor(api.search, q=query, count=100, result_type="recent", include_entities=True).pages():
        page_count += 1
        # print just the first tweet out of every page of 100 tweets
        print tweets[0].text.encode('utf-8')
        # stop after retrieving 200 pages
        if page_count >= 200:
            break

# %% [markdown]
# ## Interesting links for predicting Twitter

# %% [raw]
# Twouija: http://tweet.tarikmoon.com/
#
# Summary for non-technical audience of features used in predicting twitter retweetability:
# http://www.adigaskell.org/blog/2012/01/24/10-steps-to-twitter-heaven/
#
# https://sites.google.com/site/twitterresearch09/articles/untitledpost-1
# https://sites.google.com/site/twitterresearch09/articles/theroleofopinionleadersininterestbasedcommunities/amodelofretweets
#
# http://www.bloomagency.co.uk/using-data-to-delight-and-excite/
#
# Research Links
# http://www.mendeley.com/research-papers/search/?query=tweet
# https://sites.google.com/site/twitterresearch09/twitter-papers

# %% [markdown]
# ## Useful Snippets for Operationalizing

# %% [raw]
# Running Python as a Service in Windows
# http://stackoverflow.com/questions/32404/can-i-run-a-python-script-as-a-service-in-windows-how
# http://stackoverflow.com/questions/3783269/how-do-i-make-a-python-script-installed-as-a-service-survive-a-logout
# http://code.activestate.com/recipes/551780-win-services-helper/
#
# https://www.wakari.io/plans

# %% [markdown]
# ## Get all of the friends of a set of users

# %%
import tweepy
from tweepy import StreamListener
import json, time, sys

consumer_key        = "xLNSlDfsYDWoVDVlnUewog"
consumer_secret     = "cysEIjDiZ29J81XbMpzXndE0s7cAL5lX7XygY4G80Qc"
access_token        = "29499583-TN805p7dPVvBnaBhU5ldegeQTx16JqYMaFM8AkzSo"
access_token_secret = "dd4cSOXoruGfoykzlx6gHcSTIEQDuQkTsW4qobFyds"

# OAuth process, using the keys and tokens
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API([auth], # support for multiple authentication handlers
                     retry_count=3, retry_delay=5, retry_errors=set([401, 404, 500, 503]), # retry 3 times with 5 seconds delay when getting these error codes. For more details see https://dev.twitter.com/docs/error-codes-responses
                     monitor_rate_limit=True, wait_on_rate_limit=True # monitor remaining calls and block until replenished
                    )


# KirkDBorne, jameskobielus, timoelliott, BernardMarr, kdnuggets
follow = [534563976,14072398,15822273,108286674,20167623,485055264,18503214,39600478,14562685,339653183]

# Get the User object for twitter...
#user = api.get_user('KirkDBorne')

#print user.screen_name
#print "friends: " + str(user.friends_count)
#print "--------------------------"
#for friend in user.friends():
#   print friend.screen_name
#for user in tweepy.Cursor(api.friends, user_id='534563976').items():
#    print user.screen_name
for page in tweepy.Cursor(api.friends, user_id='534563976', count=200).pages():
    for friend in page:
        print friend.screen_name6
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-80e1c50c77d7> in <module>()
#      32 for page in tweepy.Cursor(api.friends, user_id='534563976', count=200).pages():
#      33     for friend in page:
# ---> 34         print friend.screen_name6
#
# AttributeError: 'User' object has no attribute 'screen_name6'

# %% [markdown]
# ## Merge the json files from the stream capture

# %%
import shutil, glob

outfilename = 'C:\\Projects\\ipython\\data\\twitterStreamSample' + time.strftime('%Y%m%d-%H%M%S') + '.json'

with open(outfilename, 'wb') as outfile:
    for filename in glob.glob('C:\\Projects\\ipython\\data\\*.json'):
        if filename <> outfilename:
            print filename # show progress
            with open(filename) as readfile:            
                shutil.copyfileobj(readfile, outfile)
# Out:
# C:\Projects\ipython\data\test.20140122-233108.json
# C:\Projects\ipython\data\test.20140123-064012.json
# C:\Projects\ipython\data\test.20140123-100227.json
# C:\Projects\ipython\data\twitterStreamSample_old.json

# %% [markdown]
# ## Get the most common mentions for each author in the captured tweets

# %%
#script starts with people you follow, and identifies who they retweet/mention 
#and then finds people who are popular (mentioned a lot), but who you don't
#follow

import tweepy
import json 
import time
from pprint import pprint

#filename = "C:\\Projects\\ipython\\data\\test.20140115-091256.json"
filename = "C:\\Projects\\ipython\\data\\twitterStreamSample.json"
follow = [534563976,14072398,15822273,108286674,20167623,485055264,18503214,39600478,14562685,339653183,14060372,192579441,135945569,39413322,309425789,38670441,250103509,107376471,23204397,10915042,19573968,7617702,16871339,16948477,97348240,20748873,119802433,62316970,23230622,250257799,5676402,10781952,16895951,1585,15257533,64368500,14457688,16689471,14847675,18068926,92116069,22059787,38427411,25136114,11581462,894057794,317005231,9526012,16534327,42079656,77449588,18638602,10565902,237413764,14133436,17817175,113022733,10748252,805323,259725229,23242773,33042238,16598272,15160685,14065040,14191961,16693331,803694,41788528,39804979,43878033,3709051,243465644,193030139,194081605,107938429,14184076,21393134,15481072,27549343,591248843,79275123,168282354,294405972,397450344,15612251,139169346,17850251,2981431,17204373,63875612,26412800,15298751,38790830,14746910,22238542,89440968,16688845,246346708,7480172,260909325,39345049,18318677,14093970,365453693,22631958,11344912,198483889,14065217,227423290,19825996,4921851,705287821,34155148,263830118,260582890,17043455,21922529,5727392,19123248,18914917,13860052,15344094,63109065,15374525,35186545,141752902,15106068,14596096,14994269,22773313,29649822,134908142,14761966,41381572,21566520,13455092,20453726,118030412,9965842,90478485,16816193,582199192,15336340,112717095,53257764,218155014,14066062,217488696,23114136]

with open(filename) as json_data:
    myUserList = {}
    for line in json_data:
        line = line.strip()

        data = ''
        try:
            data = json.loads(line)
        except ValueError as detail:
            #sys.stderr.write(detail.__str__() + "\n")
            continue

        if 'entities' in data and len(data['entities']['user_mentions']) > 0:
            user          = data['user']
            user_mentions = data['entities']['user_mentions']
            
            if user['id'] in follow:
                for u2 in user_mentions:                
                    myKey = "|".join([user['screen_name'],u2['screen_name']])
                    if user['id_str'] <> u2['id_str']:
                        if myKey in myUserList:
                            myUserList[myKey] += 1
                        else:
                            myUserList[myKey] = 1
                            
    # sort the list of mentions by the number of mentions
    myUserList2 = sorted(myUserList.items(), key=lambda x:x[1], reverse=True)
    for k,v in myUserList2:
        print k + "\t\t" + str(v)
# Out:
# ValaAfshar|nfl		20
# ValaAfshar|rwang0		18
# ValaAfshar|ExtremeNetworks		18
# FrankBuytendijk|Doug_Laney		17
# rwang0|ValaAfshar		14
# ValaAfshar|mkrigsman		13
# ValaAfshar|nflcio		11
# rwang0|nfl		10
# rwang0|alanlepo		9
# rwang0|elaineism		9
# rwang0|ConstellationRG		9
# FrankBuytendijk|JSussin		8
# TheSocialPitt|IBMbigdata		8
# KirkDBorne|DataScienceCtrl		7
# rwang0|Craw		7
# ValaAfshar|Craw		7
# rwang0|nflcio		6
# rwang0|ExtremeNetworks		5
# ValaAfshar|jhagel		5
# rwang0|ekolsky		5
# Natasha_D_G|KirkDBorne		4
# ValaAfshar|FoxBusiness		4
# rwang0|united		4
# rwang0|holgermu		4
# KirkDBorne|kdnuggets		4
# FrankBuytendijk|bradbox		4
# KirkDBorne|SYNTASACO		3
# FrankBuytendijk|mattdavies_uk		3
# jenstirrup|MicoYuk		3
# jenstirrup|NeilRaden		3
# ValaAfshar|LizClaman		3
# jenstirrup|howarddresner		3
# rwang0|LBrousell		3
# Natasha_D_G|IBMbigdata		3
# KirkDBorne|IBMbigdata		3
# jenstirrup|Claudia_Imhoff		3
# simonlporter|V12Nconsulting		3
# tpowlas|InaSAP		3
# FrankBuytendijk|BilalJaffery		3
# TheSocialPitt|KirkDBorne		3
# rwang0|mkrigsman		3
# jenstirrup|BIScorecard		3
# ValaAfshar|LBrousell		3
# simonlporter|t_toyota		3
# rwang0|Tourizing		3
# rwang0|PopScope		3
# bobehayes|IBMbigdata		3
# jenstirrup|nstevenlucas		3
# KirkDBorne|analyticbridge		3
# rwang0|layereddelay		3
# Natasha_D_G|jameskobielus		3
# VanRijmenam|BigDataStartups		3
# FrankBuytendijk|databeyer		3
# rwang0|normanrice3		2
# rwang0|RetailsBIGShow		2
# ValaAfshar|TeslaMotors		2
# dawnmevans|metabrown312		2
# rwang0|trackeractivity		2
# juliebhunt|wimrampen		2
# simonlporter|Assimil8		2
# rwang0|PanteliT		2
# kdnuggets|KirkDBorne		2
# slfisher|bakercom1		2
# dhinchcliffe|socialmedia2day		2
# digitalarun|mysocnet		2
# NeilRaden|nstevenlucas		2
# tinagroves|GEHealthcare		2
# rwang0|mweinbergPK		2
# tpowlas|SAPCommNet		2
# simonlporter|comparethecloud		2
# ValaAfshar|CIOMagazine		2
# simonlporter|Chilli_IT		2
# ValaAfshar|berkson0		2
# simonlporter|VMUGUK		2
# Natasha_D_G|RyMontano		2
# rwang0|marc_smith		2
# simonlporter|WiseInsGroup		2
# johnlmyers44|infomgmt		2
# Doug_Laney|BilalJaffery		2
# TheSocialPitt|VZEnterprise		2
# rwang0|Eagles		2
# NeilRaden|jenstirrup		2
# rwang0|adexchanger		2
# simonlporter|lukeXsoftware		2
# simonlporter|JohndeVoogd		2
# FrankBuytendijk|DebraMenter		2
# rwang0|studentforce		2
# HealthcareWen|VNAHealthGroup		2
# Doug_Laney|rob_chatterjee		2
# johnlmyers44|ema_research		2
# NeilRaden|Claudia_Imhoff		2
# lisaarthur|1to1Media		2
# rwang0|garyvee		2
# Natasha_D_G|IBMAnalytics		2
# rwang0|albertg2g		2
# KirkDBorne|marc_smith		2
# tamaradull|EMCcorp		2
# tunvall|MicoYuk		2
# rwang0|MechE_MBA		2
# simonlporter|Chirag69		2
# Doug_Laney|FrankBuytendijk		2
# simonlporter|ArrowECS_IBMSW		2
# ValaAfshar|dscofield		2
# rwang0|DaveMichels		2
# rwang0|CIOMagazine		2
# rwang0|dhlawrencexvii		2
# Doug_Laney|Gartner_inc		2
# rwang0|samfiorella		2
# NeilRaden|howarddresner		2
# FrankBuytendijk|Gartner_inc		2
# NeilRaden|MicoYuk		2
# simonlporter|emitsolutions		2
# simonlporter|sudipdasin		2
# Doug_Laney|JSussin		2
# simonlporter|Print2plan		2
# YvesMulkers|bakercom1		2
# Doug_Laney|mattdavies_uk		2
# eric_kavanagh|ema_research		2
# marksmithvr|SmartDataCo		2
# simonlporter|Help_Leanne		2
# simonlporter|TerrySullivan		2
# rwang0|IBMSmrtCommerce		2
# rwang0|brucedaley		2
# KirkDBorne|NeilRaden		2
# rwang0|zack_reynard		2
# rwang0|Jelly		2
# NeilRaden|BIScorecard		2
# rwang0|merv		2
# rwang0|joannaoconnell		2
# rwang0|msretail		2
# simonlporter|Alina_Lupascu		2
# mphnyc|kognitio		2
# davidfcarr|InformationWeek		2
# rwang0|Seahawks		2
# ValaAfshar|unhcio		2
# MDMGeek|ocdqblog		2
# rwang0|DetroitLionsNFL		2
# simonlporter|DublinDiana		2
# KirkDBorne|solarvps		2
# ValaAfshar|mitsmr		2
# juliebhunt|ariegoldshlager		2
# simonlporter|IBM_Software		2
# JamesMaguire|bakercom1		2
# KirkDBorne|GeorgeMasonU		1
# data_nerd|ocdqblog		1
# davidedelman|SocialEmployee		1
# rwang0|AOLNetworks		1
# rwang0|NicolasLoubet		1
# dawnmevans|deanabb		1
# MDMGeek|cdmaver		1
# timoelliott|merv		1
# simonlporter|sapo2025		1
# TheSocialPitt|SEGONE		1
# TheGrok|FaceOfBigData		1
# KirkDBorne|katsnelson		1
# tunvall|elissafink		1
# ValaAfshar|Dan_Dulac		1
# simonlporter|Autom2Marketing		1
# rwang0|SportsScrawls		1
# simonlporter|GibbsJulie		1
# dannyjpalmer|PercyBlakeney63		1
# brunoaziza|gopivotal		1
# simonlporter|cphillips_ippso		1
# tunvall|tableau		1
# rwang0|NetizenCorp		1
# mgershoff|brosnaro		1
# rwang0|philmuncaster		1
# eric_kavanagh|SQLstream		1
# YvesMulkers|kelligizzi		1
# Natasha_D_G|flavmartins		1
# rwang0|cselland		1
# Natasha_D_G|mgershoff		1
# jg21|drkleiman		1
# mjcavaretta|Ford		1
# rwang0|FoxBusiness		1
# KirkDBorne|LouisColumbus		1
# davidedelman|Reuters		1
# KirkDBorne|bigdata4hr		1
# tpowlas|samcko		1
# simonlporter|VALVESOLUTIONS		1
# KirkDBorne|BernardMarr		1
# TheSocialPitt|CrystaAnderson		1
# nancykoppdw|rjwissin		1
# KirkDBorne|Claudia_Imhoff		1
# dawnmevans|KMcCormickBlog		1
# simonlporter|iLinkx		1
# rwang0|bradkenney		1
# rwang0|KellyLiyakasa		1
# rwang0|JeffKRoss		1
# rwang0|Inflectionist		1
# MDMGeek|SASsoftware		1
# BigDataSpeaker|SocialNewsCorp		1
# simonlporter|DrZeydy		1
# rwang0|eClincher		1
# KirkDBorne|ErickaChick		1
# jamet123|Claudia_Imhoff		1
# MandiBPro|gupta		1
# simonlporter|IBMTraining		1
# simonlporter|thomaSchulz		1
# KirkDBorne|wiseio		1
# rwang0|lesliefine		1
# InfoMgmtExec|tamaradull		1
# simonlporter|shetges		1
# MDMGeek|Digitaltonto		1
# KirkDBorne|SEGONE		1
# bakercom1|IBM_Value		1
# Brian_Eastwood|JenniferLSchiff		1
# FindChrisTaylor|VentureBeat		1
# Doug_Laney|MikeNester01		1
# Natasha_D_G|chrisatyler		1
# ValaAfshar|SteveCase		1
# mjcavaretta|forditalia		1
# rwang0|brandenjenkins		1
# simonlporter|itsmcyberchick		1
# BarryDevlin|johnlmyers44		1
# Natasha_D_G|SethGrimes		1
# BigDataSpeaker|tunvall		1
# rwang0|dhinchcliffe		1
# simonlporter|TaikunInc		1
# mjcavaretta|NiemanLab		1
# rwang0|NBA		1
# KirkDBorne|xplenty		1
# rwang0|jack		1
# nancykoppdw|jfxberns		1
# eric_kavanagh|deanabb		1
# ValaAfshar|SocInnovators		1
# vijayasankarv|jbecher		1
# rwang0|fscavo		1
# SethGrimes|marie_wallace		1
# simonlporter|forrester		1
# Viktor_MS|nytimes		1
# jameskobielus|urbn		1
# marksmithvr|ventanaresearch		1
# NadhanAtHP|HP		1
# tpowlas|InformationWeek		1
# TheSocialPitt|BigDataSocial		1
# juliebhunt|jeffsussna		1
# jbdezard|BankInnovators		1
# simonlporter|DatabaseJournal		1
# tinagroves|AndiMann		1
# jbdezard|MarionBx		1
# rwang0|NRFnews		1
# TheGrok|srsworld		1
# simonlporter|Rickfer		1
# lisaarthur|Teradata		1
# NadhanAtHP|geochurch		1
# digitalarun|peers		1
# simonlporter|ARMNoel		1
# KirkDBorne|ivangruer		1
# KirkDBorne|FORR_Mgoetz		1
# simonlporter|OlofvanDuinen		1
# petervan|JeffJonas		1
# eric_kavanagh|metabrown312		1
# rwang0|GraehamF		1
# simonlporter|sharichiara		1
# simonlporter|TheCloudCTO		1
# rwang0|confiz		1
# rwang0|Ogilvy		1
# rwang0|kerrybodine		1
# ValaAfshar|ricktagious		1
# Natasha_D_G|digitarro		1
# hlsdk|DataRoundtable		1
# rwang0|jeanniecw		1
# simonlporter|eamonnkillian		1
# timoelliott|SameerPatel		1
# YvesMulkers|chris_t_omalley		1
# simonlporter|JamesMarland		1
# KirkDBorne|strataconf		1
# williammcknight|Gartner_inc		1
# nancykoppdw|kdnuggets		1
# simonlporter|card_biz		1
# rwang0|SetAgenda		1
# BeverlyMacy|SLHebner		1
# MDMGeek|Doug_Laney		1
# datagenius|SAPAnalytics		1
# Dana_Gardner|stevegereb		1
# williammcknight|Doug_Laney		1
# rwang0|sgaughen		1
# FrankBuytendijk|amythinking		1
# rwang0|PalenKantis		1
# tunvall|SAP		1
# johnlmyers44|SQLstream		1
# MandiBPro|GauravTx		1
# simonlporter|DigiBridgeSM		1
# VishalTx|stephdokin		1
# mjcavaretta|anjalorenz		1
# Doug_Laney|merv		1
# InfoMgmtExec|VishalTx		1
# rwang0|HarvardBiz		1
# datagenius|MarkGStacey		1
# timoelliott|databeyer		1
# datagenius|billfranksga		1
# rwang0|ruveng		1
# mjcavaretta|huffpo		1
# ValaAfshar|IDC		1
# YvesMulkers|VelociData		1
# TheSocialPitt|analyticbridge		1
# MandiBPro|ActianCorp		1
# KirkDBorne|Michel_Bruley		1
# simonlporter|rieffelFR		1
# mgualtieri|forrester		1
# rwang0|nporte		1
# simonlporter|cawess		1
# simonlporter|ConquerorPrime		1
# simonlporter|JBourdelin		1
# eric_kavanagh|TonyCarrini		1
# jameskobielus|LisaSeacat		1
# KirkDBorne|forrester		1
# Claudia_Imhoff|NeilRaden		1
# lisaarthur|DanGraham_		1
# NadhanAtHP|ltiano		1
# tunvall|jbecher		1
# rwang0|XeroxDocuShare		1
# ajbowles|STORMinsights		1
# BigDataSpeaker|tinagroves		1
# rwang0|nickinglis		1
# Natasha_D_G|ValaAfshar		1
# YvesMulkers|NadhanAtHP		1
# simonlporter|IBMWebSphere_es		1
# TheSocialPitt|ibmretail		1
# mjcavaretta|kasperrisbjerg		1
# jamet123|IIBA		1
# data_nerd|hyounpark		1
# simonlporter|gleonhard		1
# marcusborba|NASA		1
# ValaAfshar|bhaines0		1
# dr_morton|gruset		1
# Dana_Gardner|VentureBeat		1
# mjcavaretta|dbtrends		1
# NeilRaden|KirkDBorne		1
# YvesMulkers|Shareable		1
# simonlporter|CloudCompareIE		1
# mjcavaretta|BMCCommunities		1
# Natasha_D_G|Doug_Laney		1
# simonlporter|BizWien		1
# tcrawford|kelligizzi		1
# rwang0|KKDUB		1
# mjcavaretta|Cortica		1
# MandiBPro|Claudia_Imhoff		1
# mjcavaretta|danielaphd		1
# rwang0|NCAA		1
# mjcavaretta|luis_sarmento		1
# tpowlas|howarddresner		1
# rwang0|hharteveldt		1
# rwang0|MichaelRBarker		1
# KirkDBorne|Acculation		1
# simonlporter|soudW		1
# nancykoppdw|Infographz		1
# simonlporter|WmBender		1
# timoelliott|alanlepo		1
# timoelliott|jhagel		1
# YvesMulkers|ValaAfshar		1
# KirkDBorne|BenKerschberg		1
# TheSocialPitt|Natasha_D_G		1
# KirkDBorne|Dell		1
# rwang0|NHL		1
# simonlporter|tersoodamian		1
# johnlmyers44|eric_kavanagh		1
# ValaAfshar|RosabethKanter		1
# Doug_Laney|ParStream		1
# hlsdk|ocdqblog		1
# mphnyc|ErickaChick		1
# mjcavaretta|ryan_ar		1
# jbdezard|Happy_Laurence		1
# sandy_carter|alanghamilton		1
# craigmullins|philsimon		1
# simonlporter|Jefflittlestone		1
# rwang0|yorkecomm		1
# ITredux|SAP		1
# MandiBPro|imbigdata		1
# eric_kavanagh|infomgmt		1
# rwang0|briankrebs		1
# mjcavaretta|IBMSoftware		1
# etamb|Genesyslab		1
# davidfcarr|alanlepo		1
# rwang0|PhilJones40		1
# rwang0|WEFPics		1
# simonlporter|MattRMorrison		1
# simonlporter|alexanderlopezf		1
# ValaAfshar|LoganMJones		1
# ValaAfshar|MThiele		1
# mjcavaretta|MDMGeek		1
# Digitaltonto|practicallyrad		1
# AliRebaie|williammcknight		1
# Natasha_D_G|stevemassi		1
# ValaAfshar|CXOTalk		1
# simonlporter|cloudconireland		1
# lauriemccabe|funnelholic		1
# rwang0|ibmretail		1
# MandiBPro|KirkDBorne		1
# rwang0|knash99		1
# data_nerd|EmRCarter		1
# ValaAfshar|trendinaliaUS		1
# rwang0|papadimitriou		1
# mchui|timoreilly		1
# Doug_Laney|digitalrealty		1
# rjwissin|linkinpark		1
# ValaAfshar|JeffSheehan		1
# TheSocialPitt|infoseclegal		1
# shawnrog|TechTarget		1
# Natasha_D_G|thomasdeutsch		1
# ValaAfshar|bigthink		1
# estebanmoro|tanisjones		1
# Brian_Eastwood|VinceKuraitis		1
# datagenius|crm_plf		1
# rwang0|ron_miller		1
# simonlporter|IBMCCLon		1
# BigDataSpeaker|MDMGeek		1
# Claudia_Imhoff|jenstirrup		1
# rwang0|dordav		1
# datagenius|BigDataCloud		1
# applebyj|SCNblogs		1
# Natasha_D_G|robertsussman		1
# simonlporter|elan406		1
# RetailProphet|IBMbigdata		1
# simonlporter|HaleITweet		1
# MDMGeek|philsimon		1
# simonlporter|IBMEMM		1
# rwang0|Crystal_Jonas		1
# Doug_Laney|ted_friedman		1
# ValaAfshar|a1purva		1
# rwang0|homeclick		1
# YvesMulkers|EMCcorp		1
# simonlporter|SofterraAdaxes		1
# rwang0|askjelly		1
# KirkDBorne|gopivotal		1
# jbdezard|mitsmr		1
# lauriemccabe|CareersAtDell		1
# rwang0|FierceRetail		1
# tpowlas|njasta		1
# Doug_Laney|nheudecker		1
# rwang0|DirtyLuxuryXX		1
# ValaAfshar|skap5		1
# NadhanAtHP|Adobe		1
# simonlporter|100mbpsfiber		1
# Natasha_D_G|timoelliott		1
# simonlporter|mosquera83		1
# simonlporter|AscentPeople		1
# ValaAfshar|michael_keen		1
# rwang0|rwlord		1
# bevelson|johnrrymer		1
# jamet123|decisionmgt		1
# TheSocialPitt|Computerworld		1
# rwang0|drjoyce_knudsen		1
# mgualtieri|BradyBroz		1
# Natasha_D_G|tomfishburne		1
# simonlporter|Catalin_Crisan		1
# data_nerd|SocialEmployee		1
# rwang0|Shareable		1
# simonlporter|dcmsolusi		1
# rwang0|IBM_Value		1
# simonlporter|hgfernan		1
# InfoMgmtExec|IBM_InfoSphere		1
# simonlporter|milson		1
# rwang0|bakercom1		1
# simonlporter|Analytics_CH		1
# YvesMulkers|tcrawford		1
# simonlporter|surlaface_B		1
# simonlporter|KERENSEN		1
# YvesMulkers|NicolasLoubet		1
# rwang0|sdeanswann		1
# rwang0|eryceyl		1
# rwang0|jhagel		1
# simonlporter|JRequenaFranco		1
# rwang0|wtgltd		1
# rwang0|PAThiebaut		1
# KirkDBorne|TurboPipsMagnet		1
# imbigdata|cloudera		1
# tpowlas|debralilley		1
# rwang0|TheLudlowGroup		1
# YvesMulkers|OuiShare		1
# rwang0|indoorLBS		1
# Natasha_D_G|praxsozi		1
# Natasha_D_G|SmarterPlanet		1
# JohndeVoogd|socialmedia2day		1
# datagenius|EvansBI		1
# rwang0|hootsuite		1
# mphnyc|KirkDBorne		1
# ValaAfshar|BrianVellmure		1
# ValaAfshar|exinda		1
# Doug_Laney|caseysteve		1
# KirkDBorne|profjsb		1
# BigDataSpeaker|BigDataNewsco		1
# tinagroves|BBCNews		1
# TheSocialPitt|SiliconANGLE		1
# TonyBaer|merv		1
# digitalarun|jowyang		1
# rwang0|KnowledgeBishop		1
# rwang0|NewsGator		1
# Natasha_D_G|JulesPolonetsky		1
# FrankBuytendijk|SysMech		1
# johnlmyers44|InformationWeek		1
# datagenius|howarddresner		1
# Natasha_D_G|AliRebaie		1
# johnlmyers44|shawnrog		1
# ValaAfshar|studentforce		1
# Natasha_D_G|bobehayes		1
# simonlporter|rwang0		1
# simonlporter|Tinolle		1
# kdnuggets|marc_smith		1
# bobehayes|hadoop		1
# applebyj|njasta		1
# timoelliott|johnt		1
# tpowlas|davideparker		1
# ValaAfshar|HuffingtonPost		1
# bakercom1|rwang0		1
# datagenius|PoorBoyTreat		1
# brunoaziza|SocialEuphoria		1
# ValaAfshar|dchou1107		1
# rwang0|IanGertler		1
# simonlporter|IBMSmrtCommerce		1
# TonyBaer|timoelliott		1
# KirkDBorne|smelnik		1
# ValaAfshar|kklm7		1
# dhinchcliffe|thinkoutloud		1
# rwang0|markmadsen		1
# JohndeVoogd|BernardMarr		1
# InfoMgmtExec|openmethodology		1
# InfoMgmtExec|eggerton		1
# datagenius|NadhanAtHP		1
# simonlporter|iSocial_Fanz		1
# ValaAfshar|IdealInc		1
# ValaAfshar|collabfund		1
# mjcavaretta|lauriemccabe		1
# tamaradull|CMOAustralia		1
# simonlporter|GregorSIDERIS		1
# simonlporter|Atlantic_Intel		1
# simonlporter|SJohnKreese		1
# simonlporter|Magical_Matt1		1
# simonlporter|ASoumagne		1
# simonlporter|RebelMouse		1
# rwang0|MrSmith_1986		1
# KirkDBorne|YhatHQ		1
# InfoMgmtExec|JulesPolonetsky		1
# lisaarthur|SlideShare		1
# rwang0|TheHrbuddy		1
# rwang0|dave_austin19		1
# MDMGeek|rohinbhargava		1
# vijayasankarv|SAP		1
# simonlporter|bgbaird		1
# ValaAfshar|DeloitteDIGI_US		1
# YvesMulkers|TeslaMotors		1
# KirkDBorne|wearesocialsg		1
# rwang0|GoPro		1
# rwang0|DehliaTech		1
# rwang0|flavmartins		1
# Natasha_D_G|andrewbrust		1
# TheSocialPitt|SlideShare		1
# MDMGeek|IBMdatamag		1
# mjcavaretta|jswaroop		1
# ajbowles|Healthline		1
# FrankBuytendijk|timjpowers		1
# estebanmoro|josperello		1
# Natasha_D_G|DrMPH		1
# jamet123|darijuss		1
# simonlporter|AnalyticsWeek		1
# mjcavaretta|AliRebaie		1
# TheSocialPitt|cdmaver		1
# KirkDBorne|Cisco		1
# bakercom1|brooklyndan		1
# simonlporter|NewAdvice		1
# tunvall|SWillins		1
# JohndeVoogd|Forbes		1
# ValaAfshar|sjw		1
# rwang0|EmyGaviola		1
# rwang0|hcuervo		1
# ValaAfshar|SHarrington1		1
# VishalTx|bobehayes		1
# simonlporter|TrustGraham		1
# Natasha_D_G|QRLegend		1
# ValaAfshar|levie		1
# jameskobielus|needleit		1
# jg21|FCC		1
# marksmithvr|Bilafer		1
# mphnyc|ForbesTech		1
# Natasha_D_G|SiliconANGLE		1
# kncukier|BurtchWorks		1
# KirkDBorne|spatiotemporal		1
# rjwissin|asperasoft		1
# KirkDBorne|jameskobielus		1
# YvesMulkers|HansDeLeenheer		1
# aregenberg|bermaninstitute		1
# Viktor_MS|FlorencePoirel		1
# InfoMgmtExec|IBMbigdata		1
# simonlporter|BorisMoser		1
# KirkDBorne|marksmithvr		1
# petervan|avinash		1
# simonlporter|Nadynegh		1
# simonlporter|88main		1
# simonlporter|Vorsite		1
# simonlporter|marianbyte		1
# rwang0|Tailgate911		1
# brunoaziza|tableau		1
# KirkDBorne|IEGroup		1
# KirkDBorne|jbertolucci		1
# tpowlas|hyounpark		1
# rwang0|BoroughIndepend		1
# idin77|shane_barker		1
# davidfcarr|Podio		1
# mjcavaretta|Rainstor		1
# lauriemccabe|TechCrunch		1
# KirkDBorne|DMRadioOnline		1
# BobViolino|mashable		1
# ValaAfshar|JSussin		1
# simonlporter|glessygreat		1
# tpowlas|Patty_1982		1
# rwang0|MediaMath		1
# tcrawford|RaejeanneS		1
# marksmithvr|mikeferguson1		1
# hlsdk|AxelTroike		1
# simonlporter|Chestec		1
# YvesMulkers|rwang0		1
# YvesMulkers|tamaradull		1
# TheSocialPitt|BigDataBlogs		1
# rwang0|OuiShare		1
# mjcavaretta|GilPress		1
# SameerPatel|ekolsky		1
# rwang0|dunksr		1
# shawnrog|bevelson		1
# rwang0|MarcDiasGama		1
# craigmullins|hostgatorcodes		1
# data_nerd|DataRoundtable		1
# brunoaziza|AlpineDataLabs		1
# Natasha_D_G|JWVance		1
# rwang0|sandy_carter		1
# simonlporter|Pensar_IT		1
# ValaAfshar|aadil		1
# TheSocialPitt|MDMGeek		1
# simonlporter|andralyng		1
# YvesMulkers|schmarzo		1
# jamet123|halbatish		1
# mgershoff|fatemehx2		1
# simonlporter|bigdataindiya		1
# NadhanAtHP|ericdishman		1
# ValaAfshar|DanMamede		1
# davidedelman|KevinBrandall		1
# Natasha_D_G|UPMCnews		1
# TheGrok|TheZigZiglar		1
# rwang0|riministreet		1
# simonlporter|CloudBuzzNet		1
# rwang0|Olympics		1
# FrankBuytendijk|ted_friedman		1
# simonlporter|bthoem		1
# mphnyc|forrester		1
# rwang0|IZOInsights		1
# bobehayes|tableau		1
# YvesMulkers|BigDataClub		1
# NadhanAtHP|ECIOForum		1
# mikeolson|levie		1
# SethGrimes|SentimentSymp		1
# rwang0|JuanCPerezIDG		1
# ValaAfshar|adamjaymartin		1
# KirkDBorne|raqsoft		1
# data_nerd|GaryMarcus		1
# eric_kavanagh|johnlmyers44		1
# simonlporter|debexpert		1
# jg21|CarloPiltz		1
# simonlporter|marcobonezzi		1
# rwang0|SBSCNorthWest		1
# MDMGeek|EarlyOpter		1
# simonlporter|e_iannuzzi		1
# simonlporter|timothy_tsao		1
# simonlporter|V3_co_uk		1
# simonlporter|TeddyHK		1
# simonlporter|donadam		1
# MDMGeek|MDMTVUK		1
# rwang0|Cisco_Mobile		1
# jamet123|INFORMS		1
# simonlporter|ShowoffByDesign		1
# davidfcarr|riparian		1
# christianve|cindystarks		1
# simonlporter|adept4		1
# simonlporter|TechWeekEurope		1
# simonlporter|pbouillaud		1
# simonlporter|juarezjunior		1
# KirkDBorne|infomgmt		1
# rwang0|aassiaharoonhaq		1
# jbdezard|Finovate		1
# BigDataSpeaker|GEHealthcare		1
# rwang0|catykobe		1
# Natasha_D_G|infoseclegal		1
# eric_kavanagh|TheSocialPitt		1
# Natasha_D_G|ibmretail		1
# rwang0|JimLundy		1
# jbdezard|amycking		1
# lauriemccabe|damphoux		1
# tunvall|BigDataBorat		1
# tamaradull|NBCNews		1
# Doug_Laney|Mazlior		1
# johnlmyers44|TonyCarrini		1
# rwang0|Oracle		1
# rwang0|rhappe		1
# rwang0|ariegoldshlager		1
# rwang0|RitzCarltonHMB		1
# rwang0|Neustar		1
# ValaAfshar|IBMSocialBiz		1
# tpowlas|thorstenster		1
# brunoaziza|mrsandhill		1
# YvesMulkers|AliRebaie		1
# simonlporter|BernardMarr		1
# Digitaltonto|bhorowitz		1
# Natasha_D_G|ajbowles		1
# simonlporter|itcsecurity		1
# rwang0|dustinhaisler		1
# TheSocialPitt|imbigdata		1
# simonlporter|AnimeshSingh		1
# YvesMulkers|PhilJones40		1
# rwang0|JudithAquino		1
# bevelson|passion4process		1
# applebyj|BillRMcDermott		1
# jamet123|kimdossey		1
# ValaAfshar|CFCrowell		1
# KirkDBorne|JackVaughanatTT		1
# Natasha_D_G|InfoMgmtExec		1
# philsimon|SASsoftware		1
# KirkDBorne|WSJ		1
# tunvall|Forbes		1
# ValaAfshar|AlexOsterwalder		1
# ValaAfshar|jake_mccracken		1
# Brian_Eastwood|HealthGrinch		1
# philsimon|williammcknight		1
# rwang0|FastFit360		1
# vijayasankarv|holgermu		1
# rwang0|ArlemJM		1
# bobehayes|IBM		1
# rwang0|MLB		1
# marksmithvr|Claudia_Imhoff		1
# MDMGeek|infomgmt		1
# imbigdata|Koverse		1
# KirkDBorne|OReillyMedia		1
# KirkDBorne|cloudera		1
# nancykoppdw|sureddy		1
# Brian_Eastwood|CIOonline		1
# timoelliott|stephenwrks		1
# jg21|seikatsu		1
# ValaAfshar|lmclaughlin		1
# TheSocialPitt|eric_kavanagh		1
# KirkDBorne|annikaalford		1
# TheGrok|praveensripati		1
# rwang0|Yelp		1
# estebanmoro|sees_lab		1
# TonyBaer|databeyer		1
# rwang0|flySFO		1
# MDMGeek|IBMbigdata		1
# TheSocialPitt|kairyssdal		1
# timoelliott|SAPAnalytics		1
# timoelliott|Doug_Laney		1
# simonlporter|FelixNater		1
# rwang0|zacharyjeans		1
# ITredux|eliasisrael		1
# simonlporter|CeraselaIstrate		1
# idin77|PDRMsia		1
# BigDataSpeaker|KirkDBorne		1
# Natasha_D_G|VishalTx		1
# TheSocialPitt|bobehayes		1
# marksmithvr|applebyj		1
# davidfcarr|kjhiggins		1
# rwang0|HiperKinetic84		1
# billfranksga|BW		1
# rwang0|Michae1Green		1
# johnlmyers44|LewisUniversity		1
# kncukier|IPCinfoprivacy		1
# rwang0|berkson0		1
# simonlporter|VincentLetort		1
# Bilafer|LouisColumbus		1
# tpowlas|SAP		1
# MandiBPro|BigDataBlogs		1
# timoelliott|Gartner_inc		1
# johnlmyers44|ActianCorp		1
# rwang0|johnobeto		1
# rwang0|Steve_Lockstep		1
# jbdezard|DelphBG		1
# HealthcareWen|i_am_OTHER		1
# ValaAfshar|PhilKomarny		1
# rwang0|Lian		1
# nancykoppdw|Simplearning		1
# KirkDBorne|bigdataindiya		1
# YvesMulkers|wwsdo		1
# ValaAfshar|WhoTrendedIT		1
# YvesMulkers|JamesMaguire		1
# rwang0|MeetBallin		1
# mjcavaretta|silvioderossi		1
# marcusborba|KirkDBorne		1
# bobehayes|TheSocialPitt		1
# johnlmyers44|jamesafisher		1
# mchui|JoelGurin		1
# tamaradull|schmarzo		1
# digitalarun|instigating		1
# rwang0|avdingus		1
# NadhanAtHP|DWAnimation		1
# dannyjpalmer|Tom1Wright		1
# KirkDBorne|BigDataSpeaker		1
# YvesMulkers|DoerHub		1
# InfoMgmtExec|EMCcorp		1
# rwang0|satan1st		1
# KirkDBorne|NetOfEverything		1
# jg21|HarvardBiz		1
# simonlporter|lauriemccabe		1
# simonlporter|MPLAY_Wizzo		1
# KirkDBorne|NYUSternMSBA		1
# Doug_Laney|paulhorstmeier		1
# rwang0|_TrushitPatel		1
# eric_kavanagh|simpleisbetter		1
# simonlporter|FreeCar_		1
# TheSocialPitt|DrMPH		1
# dawnmevans|tomkhabaza		1
# KirkDBorne|mapr		1
# rwang0|wwsdo		1
# Claudia_Imhoff|nstevenlucas		1
# marksmithvr|SAPAnalytics		1
# johnlmyers44|IBMbigdata		1
# jg21|briansolis		1
# HealthcareWen|APlaceForMom		1
# FrankBuytendijk|paragshru		1
# FrankBuytendijk|Mazlior		1
# datagenius|YvesMulkers		1
# KirkDBorne|mt_marko		1
# rwang0|NetSuite		1
# VishalTx|ACCTCE		1
# jameskobielus|SmarterPlanet		1
# MandiBPro|merv		1
# hlsdk|rohinbhargava		1
# tpowlas|vijayasankarv		1
# simonlporter|AbbyWhitchurch		1
# RetailProphet|somervillemerch		1
# ValaAfshar|JohnEMichel		1
# simonlporter|KadirSahin360		1
# InfoMgmtExec|thetimes		1
# NadhanAtHP|1cloudroad		1
# mgershoff|kdnuggets		1
# simonlporter|menguy		1
# simonlporter|praxsozi		1
# mjcavaretta|spreadthelogic		1
# KirkDBorne|albertocairo		1
# datagenius|ramirogoncalez		1
# simonlporter|dthepot		1
# datagenius|herberts		1
# ValaAfshar|BobLaliberte		1
# johnlmyers44|donalddotfarmer		1
# mgualtieri|Nikopol_TO		1
# InfoMgmtExec|Natasha_D_G		1
# bobehayes|IBMAnalytics		1
# jameskobielus|profngross		1
# Dana_Gardner|theopengroup		1
# simonlporter|idin77		1
# simonlporter|HaleChris		1
# idin77|patseers		1
# BeverlyMacy|TheCR		1
# KirkDBorne|resdatall		1
# FindChrisTaylor|robdelaney		1
# mjcavaretta|ChrisNerney		1
# simonlporter|luisdans		1
# KirkDBorne|sDataManagement		1
# rwang0|_partnership		1
# simonlporter|Galahad_uk		1
# idin77|PDRMsia_Trafik		1
# MDMGeek|Ruben_Knudsen		1
# KirkDBorne|VisualCueTech		1
# marksmithvr|nicfish		1
# mjcavaretta|CITEworld		1
# BeverlyMacy|Kristi_Eells		1
# BigDataSpeaker|CSC_Analytics		1
# marcusborba|meganigannon		1
# Natasha_D_G|tcrawford		1
# marksmithvr|IBM		1
# KirkDBorne|mappingBIGdata		1
# TheSocialPitt|JulesPolonetsky		1
# jamet123|JohndeVoogd		1
# Claudia_Imhoff|BIScorecard		1
# tpowlas|holgermu		1
# ITredux|jbecher		1
# rwang0|mataylor67		1
# rwang0|salesforce		1
# mjcavaretta|AndiMann		1
# Natasha_D_G|eggerton		1
# mjcavaretta|LOMBARDI_GLORIA		1
# Natasha_D_G|Bilafer		1
# simonlporter|TrojanSolutions		1
# rwang0|EVANDUVAL		1
# Claudia_Imhoff|howarddresner		1
# YvesMulkers|RaejeanneS		1
# Claudia_Imhoff|MicoYuk		1
# rwang0|nasscom		1
# HealthcareWen|sherlbrn		1
# tunvall|docbaty		1
# NadhanAtHP|co3sys		1
# johnlmyers44|SAP		1
# InfoMgmtExec|darijuss		1
# KirkDBorne|Hixgrid		1
# Natasha_D_G|RetailProphet		1
# rwang0|russn		1
# ValaAfshar|Kimsstevenson		1
# johnlmyers44|QlikView		1
# InfoMgmtExec|CrystaAnderson		1
# rwang0|jilltwiss		1
# simonlporter|HockeyStickWkly		1
# rwang0|nabomita_smiles		1
# marcusborba|SPACEdotcom		1
# simonlporter|LP3Sam		1
# digitalarun|NYU_CUSP		1
# ValaAfshar|chipsuttles		1
# simonlporter|RangaDesh		1
# jg21|TomWheelerFCC		1
# jg21|IlvesToomas		1
# ValaAfshar|jhegal		1
